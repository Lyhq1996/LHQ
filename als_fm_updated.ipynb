# %% [markdown]
# # MODEL 1: ALS Estimator Using Spark

# %% [markdown]
# ### Step 1 : Set up the environment / necessary housekeeping

# %%
# !pip install --upgrade pip
# !pip install -q findspark
# Out:
# Requirement already up-to-date: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (20.0.2)

# %%
#install spark
import pyspark
 # get a spark context
sc = pyspark.SparkContext.getOrCreate()
print(sc)
# get a spark session
spark = pyspark.sql.SparkSession.builder.getOrCreate()
print(spark)
spark.version
# Out:
# <SparkContext master=local[*] appName=pyspark-shell>
# <pyspark.sql.session.SparkSession object at 0x7f0b47595198>
# '2.3.4'

# %%
#import findspark
#findspark.init("spark-2.4.5-bin-hadoop2.7")

# %% [markdown]
# ### Step 2 : Load data

# %%
#download the relevant dataset directly from grouplens
# !wget http://files.grouplens.org/datasets/movielens/ml-latest-small.zip
#unzip the movielens zip file
# !unzip -o ml-latest-small.zip
# Out:
# --2020-04-28 13:50:48--  http://files.grouplens.org/datasets/movielens/ml-latest-small.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 978202 (955K) [application/zip]
# Saving to: ‘ml-latest-small.zip.2’
#
# ml-latest-small.zip 100%[===================>] 955.28K  --.-KB/s    in 0.1s
#
# 2020-04-28 13:50:48 (6.42 MB/s) - ‘ml-latest-small.zip.2’ saved [978202/978202]
#
# Archive:  ml-latest-small.zip
#   inflating: ml-latest-small/links.csv
#   inflating: ml-latest-small/tags.csv
#   inflating: ml-latest-small/ratings.csv
#   inflating: ml-latest-small/README.txt
#   inflating: ml-latest-small/movies.csv

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql.types import StructType
from pyspark.sql.types import StructField
from pyspark.sql.types import *
import pandas as pd
import numpy as np

# %%
# create a SparkSession
spark = SparkSession.builder.getOrCreate()  

data_movie=pd.read_csv("ml-latest-small/movies.csv")
df_movie=spark.createDataFrame(data_movie)
df_movie.show()

data_ratings=pd.read_csv("ml-latest-small/ratings.csv")
df_ratings=spark.createDataFrame(data_ratings)
df_ratings.show()

data_tags=pd.read_csv("ml-latest-small/tags.csv")
df_tags=spark.createDataFrame(data_tags)
df_tags.show()

df_ratings.createOrReplaceTempView('ratings') 
df_movie.createOrReplaceTempView('movie') 
df_tags.createOrReplaceTempView('tags')
# Out:
# +-------+--------------------+--------------------+
# |movieId|               title|              genres|
# +-------+--------------------+--------------------+
# |      1|    Toy Story (1995)|Adventure|Animati...|
# |      2|      Jumanji (1995)|Adventure|Childre...|
# |      3|Grumpier Old Men ...|      Comedy|Romance|
# |      4|Waiting to Exhale...|Comedy|Drama|Romance|
# |      5|Father of the Bri...|              Comedy|
# |      6|         Heat (1995)|Action|Crime|Thri...|
# |      7|      Sabrina (1995)|      Comedy|Romance|
# |      8| Tom and Huck (1995)|  Adventure|Children|
# |      9| Sudden Death (1995)|              Action|
# |     10|    GoldenEye (1995)|Action|Adventure|...|
# |     11|American Presiden...|Comedy|Drama|Romance|
# |     12|Dracula: Dead and...|       Comedy|Horror|
# |     13|        Balto (1995)|Adventure|Animati...|
# |     14|        Nixon (1995)|               Drama|
# |     15|Cutthroat Island ...|Action|Adventure|...|
# |     16|       Casino (1995)|         Crime|Drama|
# |     17|Sense and Sensibi...|       Drama|Romance|
# |     18|   Four Rooms (1995)|              Comedy|
# |     19|Ace Ventura: When...|              Comedy|
# |     20|  Money Train (1995)|Action|Comedy|Cri...|
# +-------+--------------------+--------------------+
# only showing top 20 rows
#
# +------+-------+------+---------+
# |userId|movieId|rating|timestamp|
# +------+-------+------+---------+
# |     1|      1|   4.0|964982703|
# |     1|      3|   4.0|964981247|
# |     1|      6|   4.0|964982224|
# |     1|     47|   5.0|964983815|
# |     1|     50|   5.0|964982931|
# |     1|     70|   3.0|964982400|
# |     1|    101|   5.0|964980868|
# |     1|    110|   4.0|964982176|
# |     1|    151|   5.0|964984041|
# |     1|    157|   5.0|964984100|
# |     1|    163|   5.0|964983650|
# |     1|    216|   5.0|964981208|
# |     1|    223|   3.0|964980985|
# |     1|    231|   5.0|964981179|
# |     1|    235|   4.0|964980908|
# |     1|    260|   5.0|964981680|
# |     1|    296|   3.0|964982967|
# |     1|    316|   3.0|964982310|
# |     1|    333|   5.0|964981179|
# |     1|    349|   4.0|964982563|
# +------+-------+------+---------+
# only showing top 20 rows
#
# +------+-------+-----------------+----------+
# |userId|movieId|              tag| timestamp|
# +------+-------+-----------------+----------+
# |     2|  60756|            funny|1445714994|
# |     2|  60756|  Highly quotable|1445714996|
# |     2|  60756|     will ferrell|1445714992|
# |     2|  89774|     Boxing story|1445715207|
# |     2|  89774|              MMA|1445715200|
# |     2|  89774|        Tom Hardy|1445715205|
# |     2| 106782|            drugs|1445715054|
# |     2| 106782|Leonardo DiCaprio|1445715051|
# |     2| 106782|  Martin Scorsese|1445715056|
# |     7|  48516|     way too long|1169687325|
# |    18|    431|        Al Pacino|1462138765|
# |    18|    431|         gangster|1462138749|
# |    18|    431|            mafia|1462138755|
# |    18|   1221|        Al Pacino|1461699306|
# |    18|   1221|            Mafia|1461699303|
# |    18|   5995|        holocaust|1455735472|
# |    18|   5995|       true story|1455735479|
# |    18|  44665|     twist ending|1456948283|
# |    18|  52604|  Anthony Hopkins|1457650696|
# |    18|  52604|  courtroom drama|1457650711|
# +------+-------+-----------------+----------+
# only showing top 20 rows

# %%
# split into test and training set
(training, test) = df_ratings.randomSplit([0.8, 0.2]) 
#show columns of training dataset
training.printSchema() 
#show the size of training and test dataset
print(training.count()) 
print(test.count())
# Out:
# root
#  |-- userId: long (nullable = true)
#  |-- movieId: long (nullable = true)
#  |-- rating: double (nullable = true)
#  |-- timestamp: long (nullable = true)
#
# 80588
# 20248

# %% [markdown]
# ### Step 3 : Create a baseline

# %%
#get the average rating and show the result
SQL1 = 'SELECT AVG(rating) FROM ratings'
row = spark.sql(SQL1).collect()[0] 

#access Row as a map 
meanRating = row['avg(rating)'] 
print('meanRating',meanRating)

#get the se as rdd
se_rdd = test.rdd.map(lambda row: Row(se = pow(row['rating']-meanRating,2)) ) 
se_df = spark.createDataFrame(se_rdd) 
se_df.createOrReplaceTempView('se')
print('se_df',se_df)

#calculate the average se as rmse
SQL2 = 'SELECT AVG(se) FROM se'
row = spark.sql(SQL2).collect()[0]
meanSE = row['avg(se)'] # access Row as a map 
print('RMSE',pow(meanSE,0.5))
# Out:
# meanRating 3.501556983616962
# se_df DataFrame[se: double]
# RMSE 1.0477444165970882

# %% [markdown]
# ### Step 4 : train ALS estimator and perform cross validation

# %%
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder, TrainValidationSplit
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.recommendation import ALS

# Build the recommendation model using ALS on the training data
als = ALS(maxIter=3, rank=10, regParam=0.1, userCol="userId", itemCol="movieId", ratingCol="rating",coldStartStrategy="drop")

#Set the parameter grid
paramGrid = ParamGridBuilder() \
  .addGrid(als.regParam, [0.03,0.1,0.3]) \
  .addGrid(als.rank, [3,10,30]).build()

regEval = RegressionEvaluator(metricName="rmse", labelCol="rating", predictionCol="prediction")

#Start the cross validation and fit on the training dataset 
crossVal = CrossValidator(estimator=als, estimatorParamMaps=paramGrid, evaluator=regEval)
cvModel = crossVal.fit(training)

# %%
# Show the metrics form the CrossValidation
print(cvModel.avgMetrics) 

# Gives us the parameter combinations
print(cvModel.getEstimatorParamMaps()) 
paramMap = list(zip(cvModel.getEstimatorParamMaps(),cvModel.avgMetrics))

# Print the parameter that gives us the smallest rmse
paramMin = min(paramMap, key=lambda x: x[1])
print(paramMin)
# Out:
# [1.0425361595819607, 1.120488711370013, 1.2083832440684281, 0.9475788147872286, 0.9535126910421409, 0.9436016488068664, 0.9388136990938469, 0.9482871322438656, 0.9565371915485148]
# [{Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.03, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 3}, {Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.03, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 10}, {Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.03, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 30}, {Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.1, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 3}, {Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.1, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 10}, {Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.1, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 30}, {Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.3, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 3}, {Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.3, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 10}, {Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.3, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 30}]
# ({Param(parent='ALS_43ada2e1d01b56419307', name='regParam', doc='regularization parameter (>= 0).'): 0.3, Param(parent='ALS_43ada2e1d01b56419307', name='rank', doc='rank of the factorization'): 3}, 0.9388136990938469)

# %%
#Implement the als model with the best parameter
als = ALS(maxIter=3, rank=3, regParam=0.3, userCol="userId", itemCol="movieId", ratingCol="rating",
          coldStartStrategy="drop")
model = als.fit(training)

# %%
# Evaluate the model by computing the RMSE on the test data
predictions = model.transform(test)
evaluator = RegressionEvaluator(metricName="rmse", labelCol="rating",
                                predictionCol="prediction")
rmse = evaluator.evaluate(predictions)
print("RMSE = " + str(rmse))
# Out:
# RMSE = 0.9208259381006187

# %%
#Get the prediction result
predictions.show()
predictions.createOrReplaceTempView('predictions')
# Out:
# +------+-------+------+----------+----------+
# |userId|movieId|rating| timestamp|prediction|
# +------+-------+------+----------+----------+
# |    91|    471|   1.0|1112713817|  3.420579|
# |   409|    471|   3.0| 967912821| 3.6859088|
# |    57|    471|   3.0| 969753604| 3.3666618|
# |   217|    471|   2.0| 955943727| 2.9410295|
# |   136|    471|   4.0| 832450058| 3.3150916|
# |   171|    471|   3.0| 866905683| 4.3078547|
# |   273|    471|   5.0| 835861348|   3.90487|
# |   216|    471|   3.0| 975212641| 3.3883548|
# |   469|    471|   5.0| 965425364| 3.5002356|
# |   426|    471|   5.0|1451081135| 3.3723133|
# |   492|    833|   4.0| 863976674| 2.0843596|
# |   463|   1088|   3.5|1145460096| 3.4565172|
# |   599|   1088|   2.5|1498515232| 2.6232772|
# |   221|   1088|   3.0|1111178147| 3.4920092|
# |    68|   1088|   3.5|1158534614| 3.0066447|
# |   517|   1088|   1.0|1487958398| 2.2101922|
# |    19|   1238|   3.0| 965705784| 3.1612732|
# |   156|   1238|   4.0| 946799272| 3.9335265|
# |   469|   1238|   5.0| 965425364| 4.0281415|
# |   599|   1342|   2.5|1498516773| 1.9109716|
# +------+-------+------+----------+----------+
# only showing top 20 rows

# %% [markdown]
# ### Step 5 : Movie recommendation results

# %%
# Get top 5 movie recommendations for each user
userRecs = model.recommendForAllUsers(10)
userRecs.show()
# Get top 5 user recommendations for each movie
movieRecs = model.recommendForAllItems(10)
# Out:
# +------+--------------------+
# |userId|     recommendations|
# +------+--------------------+
# |   471|[[3567, 5.126542]...|
# |   463|[[25947, 5.370457...|
# |   496|[[3567, 4.7320633...|
# |   148|[[3567, 4.909178]...|
# |   540|[[3567, 5.8491163...|
# |   392|[[3567, 4.7341595...|
# |   243|[[40491, 6.575885...|
# |    31|[[6818, 5.632965]...|
# |   516|[[3567, 5.20283],...|
# |   580|[[25947, 4.971461...|
# |   251|[[3567, 6.2263536...|
# |   451|[[40491, 5.669374...|
# |    85|[[3567, 5.364459]...|
# |   137|[[3567, 5.3103585...|
# |    65|[[3567, 5.3338385...|
# |   458|[[40491, 6.331005...|
# |   481|[[3567, 4.654888]...|
# |    53|[[40491, 7.361403...|
# |   255|[[3567, 3.836444]...|
# |   588|[[3567, 4.773695]...|
# +------+--------------------+
# only showing top 20 rows

# %%
# Get top 5 movie recommendations for a specified set of users
users = df_ratings.select(als.getUserCol()).distinct().limit(3)
userSubsetRecs = model.recommendForUserSubset(users, 5)

# Get top 5 user recommendations for a specified set of movies
movies = df_ratings.select(als.getItemCol()).distinct().limit(3)
movieSubSetRecs = model.recommendForItemSubset(movies, 5)

# %%
df_rec=userRecs.toPandas()
df_rec[df_rec.userId==198].recommendations
# Out:
# 523    [(3567, 5.105193138122559), (6818, 5.100881099...
# Name: recommendations, dtype: object

# %% [markdown]
# # Surprise

# %%
# !pip install scikit-surprise
import surprise
from surprise import Reader, Dataset
# Out:
# Requirement already satisfied: scikit-surprise in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.1.0)
# Requirement already satisfied: six>=1.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-surprise) (1.11.0)
# Requirement already satisfied: scipy>=1.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-surprise) (1.1.0)
# Requirement already satisfied: numpy>=1.11.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-surprise) (1.18.3)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-surprise) (0.14.1)

# %%
data_ratings = data_ratings[['userId', 'movieId', 'rating', 'timestamp']]
data_ratings = data_ratings.iloc[:, :-1]
reader = Reader()
data = Dataset.load_from_df(data_ratings[['userId', 'movieId', 'rating']], reader)

# %%
from surprise.model_selection import train_test_split

trainset, testset = train_test_split(data, test_size=0.2)

# %%
from surprise import SVD, accuracy
alg_svd = SVD()
alg_svd.fit(trainset)

# %%
pred_svd= alg_svd.test(testset)
pred_svd
# Out:
# [Prediction(uid=424, iid=54503, r_ui=4.0, est=3.8650737211165316, details={'was_impossible': False}),
#  Prediction(uid=603, iid=156, r_ui=2.0, est=3.4555683174045337, details={'was_impossible': False}),
#  Prediction(uid=493, iid=1214, r_ui=2.0, est=4.093950837057857, details={'was_impossible': False}),
#  Prediction(uid=357, iid=74458, r_ui=4.0, est=4.248652933115986, details={'was_impossible': False}),
#  Prediction(uid=599, iid=1307, r_ui=3.0, est=3.4255894185149813, details={'was_impossible': False}),
#  Prediction(uid=21, iid=114818, r_ui=1.0, est=3.186473081561313, details={'was_impossible': False}),
#  Prediction(uid=153, iid=6377, r_ui=1.0, est=2.6819338692676884, details={'was_impossible': False}),
#  Prediction(uid=208, iid=198, r_ui=2.0, est=3.2681263591649152, details={'was_impossible': False}),
#  Prediction(uid=474, iid=5707, r_ui=3.0, est=3.0482276496725045, details={'was_impossible': False}),
#  Prediction(uid=122, iid=3949, r_ui=5.0, est=4.849815889508664, details={'was_impossible': False}),
#  Prediction(uid=610, iid=135803, r_ui=3.5, est=3.5805714380866847, details={'was_impossible': False}),
#  Prediction(uid=199, iid=2858, r_ui=5.0, est=3.3914235095044263, details={'was_impossible': False}),
#  Prediction(uid=240, iid=95, r_ui=5.0, est=4.0199662333789, details={'was_impossible': False}),
#  Prediction(uid=143, iid=79132, r_ui=2.0, est=3.7094664227827674, details={'was_impossible': False}),
#  Prediction(uid=448, iid=5523, r_ui=2.0, est=2.8928853962602794, details={'was_impossible': False}),
#  Prediction(uid=537, iid=106782, r_ui=5.0, est=4.130706318265135, details={'was_impossible': False}),
#  Prediction(uid=105, iid=131237, r_ui=5.0, est=3.9376615217076534, details={'was_impossible': False}),
#  Prediction(uid=424, iid=58559, r_ui=3.5, est=4.256720790765316, details={'was_impossible': False}),
#  Prediction(uid=594, iid=1784, r_ui=3.0, est=3.803227409834493, details={'was_impossible': False}),
#  Prediction(uid=381, iid=7143, r_ui=4.5, est=4.150410739545083, details={'was_impossible': False}),
#  Prediction(uid=62, iid=102123, r_ui=4.0, est=3.852973676051779, details={'was_impossible': False}),
#  Prediction(uid=182, iid=2117, r_ui=4.0, est=3.6133401127121374, details={'was_impossible': False}),
#  Prediction(uid=351, iid=8533, r_ui=4.0, est=3.5694490969189587, details={'was_impossible': False}),
#  Prediction(uid=190, iid=8533, r_ui=3.0, est=3.6673351643800607, details={'was_impossible': False}),
#  Prediction(uid=480, iid=47044, r_ui=4.0, est=2.4158232358600125, details={'was_impossible': False}),
#  Prediction(uid=561, iid=3255, r_ui=4.0, est=3.237850316219797, details={'was_impossible': False}),
#  Prediction(uid=454, iid=79008, r_ui=3.5, est=3.913225201287377, details={'was_impossible': False}),
#  Prediction(uid=21, iid=31685, r_ui=3.5, est=3.230953112389478, details={'was_impossible': False}),
#  Prediction(uid=562, iid=99007, r_ui=4.0, est=4.0359013220191375, details={'was_impossible': False}),
#  Prediction(uid=274, iid=1461, r_ui=4.0, est=2.664609897113333, details={'was_impossible': False}),
#  Prediction(uid=377, iid=7706, r_ui=4.0, est=4.227599183488926, details={'was_impossible': False}),
#  Prediction(uid=66, iid=1224, r_ui=4.5, est=3.9029727789550956, details={'was_impossible': False}),
#  Prediction(uid=587, iid=1193, r_ui=5.0, est=4.335540198718812, details={'was_impossible': False}),
#  Prediction(uid=279, iid=71838, r_ui=3.5, est=3.032621053599878, details={'was_impossible': False}),
#  Prediction(uid=199, iid=1060, r_ui=5.0, est=3.2126879151359047, details={'was_impossible': False}),
#  Prediction(uid=356, iid=2502, r_ui=3.5, est=4.180148426517246, details={'was_impossible': False}),
#  Prediction(uid=380, iid=58025, r_ui=3.5, est=3.181292956044519, details={'was_impossible': False}),
#  Prediction(uid=298, iid=111659, r_ui=1.0, est=1.7598983070938161, details={'was_impossible': False}),
#  Prediction(uid=555, iid=3702, r_ui=4.0, est=3.5391743535576223, details={'was_impossible': False}),
#  Prediction(uid=434, iid=1, r_ui=4.0, est=3.7003464512016015, details={'was_impossible': False}),
#  Prediction(uid=89, iid=44022, r_ui=1.0, est=3.44023562857494, details={'was_impossible': False}),
#  Prediction(uid=200, iid=6383, r_ui=4.0, est=2.757200403976559, details={'was_impossible': False}),
#  Prediction(uid=596, iid=3751, r_ui=2.0, est=3.4985923406816495, details={'was_impossible': False}),
#  Prediction(uid=606, iid=30803, r_ui=4.5, est=3.4779671632422584, details={'was_impossible': False}),
#  Prediction(uid=89, iid=30793, r_ui=2.0, est=3.3355300372840606, details={'was_impossible': False}),
#  Prediction(uid=514, iid=115713, r_ui=3.0, est=3.5255123554413017, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6266, r_ui=3.0, est=2.848837767969411, details={'was_impossible': False}),
#  Prediction(uid=509, iid=5971, r_ui=4.0, est=3.80414153522465, details={'was_impossible': False}),
#  Prediction(uid=599, iid=4477, r_ui=1.5, est=2.0472219475979885, details={'was_impossible': False}),
#  Prediction(uid=548, iid=1393, r_ui=5.0, est=3.9998396603767192, details={'was_impossible': False}),
#  Prediction(uid=148, iid=134853, r_ui=4.0, est=3.523653377221786, details={'was_impossible': False}),
#  Prediction(uid=405, iid=76251, r_ui=4.0, est=3.9246256532061943, details={'was_impossible': False}),
#  Prediction(uid=91, iid=1377, r_ui=3.0, est=2.7185720318902047, details={'was_impossible': False}),
#  Prediction(uid=610, iid=51077, r_ui=2.0, est=2.8902344399114845, details={'was_impossible': False}),
#  Prediction(uid=221, iid=2908, r_ui=4.5, est=4.4068231689370005, details={'was_impossible': False}),
#  Prediction(uid=414, iid=7258, r_ui=3.0, est=3.11399463932864, details={'was_impossible': False}),
#  Prediction(uid=474, iid=2006, r_ui=4.0, est=2.797824292953013, details={'was_impossible': False}),
#  Prediction(uid=541, iid=413, r_ui=1.0, est=2.9702472146006236, details={'was_impossible': False}),
#  Prediction(uid=160, iid=1960, r_ui=1.0, est=3.0524282823068933, details={'was_impossible': False}),
#  Prediction(uid=596, iid=31221, r_ui=2.5, est=2.7325250674040156, details={'was_impossible': False}),
#  Prediction(uid=288, iid=4976, r_ui=4.0, est=2.940185803062865, details={'was_impossible': False}),
#  Prediction(uid=19, iid=3361, r_ui=2.0, est=3.3251637043482196, details={'was_impossible': False}),
#  Prediction(uid=249, iid=5502, r_ui=3.0, est=3.4634892678809703, details={'was_impossible': False}),
#  Prediction(uid=460, iid=34405, r_ui=5.0, est=4.1781444991724825, details={'was_impossible': False}),
#  Prediction(uid=160, iid=1645, r_ui=3.0, est=2.7355980982418955, details={'was_impossible': False}),
#  Prediction(uid=522, iid=47200, r_ui=2.5, est=3.2806337255580886, details={'was_impossible': False}),
#  Prediction(uid=414, iid=991, r_ui=4.0, est=3.4394891765171756, details={'was_impossible': False}),
#  Prediction(uid=318, iid=541, r_ui=3.5, est=4.0976091301908015, details={'was_impossible': False}),
#  Prediction(uid=599, iid=5049, r_ui=3.0, est=2.8294026575113085, details={'was_impossible': False}),
#  Prediction(uid=24, iid=58998, r_ui=4.0, est=3.722458881854566, details={'was_impossible': False}),
#  Prediction(uid=520, iid=3408, r_ui=4.0, est=3.8783182135786487, details={'was_impossible': False}),
#  Prediction(uid=68, iid=67255, r_ui=4.5, est=4.061823051785716, details={'was_impossible': False}),
#  Prediction(uid=140, iid=4056, r_ui=4.0, est=3.3894379925949822, details={'was_impossible': False}),
#  Prediction(uid=401, iid=5882, r_ui=5.0, est=3.2244633947918566, details={'was_impossible': False}),
#  Prediction(uid=288, iid=2918, r_ui=3.5, est=3.645529799459141, details={'was_impossible': False}),
#  Prediction(uid=328, iid=2641, r_ui=4.5, est=2.7176995638628574, details={'was_impossible': False}),
#  Prediction(uid=572, iid=2006, r_ui=3.0, est=3.5556628396628995, details={'was_impossible': False}),
#  Prediction(uid=414, iid=64614, r_ui=4.0, est=3.9220088540070135, details={'was_impossible': False}),
#  Prediction(uid=177, iid=1198, r_ui=3.5, est=3.9345118283180707, details={'was_impossible': False}),
#  Prediction(uid=125, iid=7022, r_ui=5.0, est=4.194009899362441, details={'was_impossible': False}),
#  Prediction(uid=307, iid=2496, r_ui=1.5, est=2.9677986201356497, details={'was_impossible': False}),
#  Prediction(uid=274, iid=3286, r_ui=2.5, est=3.2118804291212335, details={'was_impossible': False}),
#  Prediction(uid=460, iid=7147, r_ui=4.0, est=4.100330291548935, details={'was_impossible': False}),
#  Prediction(uid=599, iid=2529, r_ui=4.0, est=3.1423602456624793, details={'was_impossible': False}),
#  Prediction(uid=597, iid=1302, r_ui=5.0, est=3.764916989609716, details={'was_impossible': False}),
#  Prediction(uid=380, iid=106487, r_ui=3.0, est=3.5223155068533623, details={'was_impossible': False}),
#  Prediction(uid=590, iid=1206, r_ui=3.0, est=3.618232121431368, details={'was_impossible': False}),
#  Prediction(uid=328, iid=1375, r_ui=3.5, est=2.8348706198749842, details={'was_impossible': False}),
#  Prediction(uid=53, iid=1049, r_ui=5.0, est=4.388695726031053, details={'was_impossible': False}),
#  Prediction(uid=307, iid=4371, r_ui=0.5, est=2.594413766568117, details={'was_impossible': False}),
#  Prediction(uid=567, iid=76093, r_ui=2.5, est=2.7793411374940376, details={'was_impossible': False}),
#  Prediction(uid=121, iid=457, r_ui=3.0, est=3.8265551939627103, details={'was_impossible': False}),
#  Prediction(uid=558, iid=5171, r_ui=5.0, est=3.4031800887210113, details={'was_impossible': False}),
#  Prediction(uid=249, iid=8961, r_ui=4.0, est=4.04812126860899, details={'was_impossible': False}),
#  Prediction(uid=305, iid=48774, r_ui=3.5, est=4.197825858787302, details={'was_impossible': False}),
#  Prediction(uid=477, iid=1278, r_ui=4.0, est=4.582144264254386, details={'was_impossible': False}),
#  Prediction(uid=365, iid=61132, r_ui=3.5, est=3.1470450127646985, details={'was_impossible': False}),
#  Prediction(uid=177, iid=2628, r_ui=2.0, est=2.6433089925549185, details={'was_impossible': False}),
#  Prediction(uid=414, iid=1792, r_ui=3.0, est=2.6816107420842896, details={'was_impossible': False}),
#  Prediction(uid=396, iid=745, r_ui=4.0, est=3.160468102781799, details={'was_impossible': False}),
#  Prediction(uid=448, iid=30810, r_ui=3.0, est=3.0924428661027097, details={'was_impossible': False}),
#  Prediction(uid=105, iid=6214, r_ui=4.5, est=4.3221095888081615, details={'was_impossible': False}),
#  Prediction(uid=63, iid=122892, r_ui=4.0, est=3.49782384001032, details={'was_impossible': False}),
#  Prediction(uid=103, iid=1084, r_ui=5.0, est=3.9462964467854236, details={'was_impossible': False}),
#  Prediction(uid=524, iid=737, r_ui=3.0, est=2.7321032547137345, details={'was_impossible': False}),
#  Prediction(uid=10, iid=72737, r_ui=3.5, est=3.1721520415602895, details={'was_impossible': False}),
#  Prediction(uid=356, iid=5666, r_ui=5.0, est=3.6776009926681748, details={'was_impossible': False}),
#  Prediction(uid=608, iid=4310, r_ui=3.0, est=2.613377247073729, details={'was_impossible': False}),
#  Prediction(uid=543, iid=2959, r_ui=5.0, est=4.8661436458223255, details={'was_impossible': False}),
#  Prediction(uid=98, iid=60040, r_ui=4.0, est=3.5181562839463623, details={'was_impossible': False}),
#  Prediction(uid=573, iid=48774, r_ui=4.5, est=4.226680319873898, details={'was_impossible': False}),
#  Prediction(uid=232, iid=7155, r_ui=0.5, est=3.3439553767306314, details={'was_impossible': False}),
#  Prediction(uid=365, iid=5378, r_ui=2.5, est=2.466844106920401, details={'was_impossible': False}),
#  Prediction(uid=438, iid=3981, r_ui=3.0, est=3.0871903942111207, details={'was_impossible': False}),
#  Prediction(uid=573, iid=45722, r_ui=5.0, est=4.239735784721927, details={'was_impossible': False}),
#  Prediction(uid=339, iid=41566, r_ui=3.0, est=4.018084058534024, details={'was_impossible': False}),
#  Prediction(uid=42, iid=612, r_ui=2.0, est=3.5596522966940727, details={'was_impossible': False}),
#  Prediction(uid=18, iid=4262, r_ui=4.0, est=3.989451619012137, details={'was_impossible': False}),
#  Prediction(uid=132, iid=7320, r_ui=3.0, est=2.8559728364832075, details={'was_impossible': False}),
#  Prediction(uid=414, iid=4220, r_ui=4.0, est=3.7626813347884895, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6238, r_ui=0.5, est=2.283688780372309, details={'was_impossible': False}),
#  Prediction(uid=533, iid=1, r_ui=5.0, est=4.338836427999297, details={'was_impossible': False}),
#  Prediction(uid=448, iid=82499, r_ui=2.5, est=2.735620331049847, details={'was_impossible': False}),
#  Prediction(uid=534, iid=3300, r_ui=4.5, est=3.810736156280937, details={'was_impossible': False}),
#  Prediction(uid=480, iid=3826, r_ui=1.0, est=1.947426564480129, details={'was_impossible': False}),
#  Prediction(uid=420, iid=3534, r_ui=3.0, est=3.376837048512245, details={'was_impossible': False}),
#  Prediction(uid=313, iid=1356, r_ui=2.0, est=3.822658427453417, details={'was_impossible': False}),
#  Prediction(uid=263, iid=5349, r_ui=4.0, est=3.771213558851229, details={'was_impossible': False}),
#  Prediction(uid=606, iid=2010, r_ui=5.0, est=3.9732898166747677, details={'was_impossible': False}),
#  Prediction(uid=567, iid=114180, r_ui=1.0, est=2.2990306517648067, details={'was_impossible': False}),
#  Prediction(uid=599, iid=6870, r_ui=3.5, est=3.1982905117869365, details={'was_impossible': False}),
#  Prediction(uid=64, iid=786, r_ui=3.0, est=3.2196804882947974, details={'was_impossible': False}),
#  Prediction(uid=480, iid=27882, r_ui=3.0, est=3.396161429007472, details={'was_impossible': False}),
#  Prediction(uid=602, iid=410, r_ui=4.0, est=2.971615712400192, details={'was_impossible': False}),
#  Prediction(uid=542, iid=2858, r_ui=4.5, est=4.003970260714211, details={'was_impossible': False}),
#  Prediction(uid=19, iid=1339, r_ui=2.0, est=2.7869176530567166, details={'was_impossible': False}),
#  Prediction(uid=314, iid=786, r_ui=3.0, est=3.013127087783806, details={'was_impossible': False}),
#  Prediction(uid=104, iid=41566, r_ui=4.5, est=3.2993367675106793, details={'was_impossible': False}),
#  Prediction(uid=6, iid=317, r_ui=4.0, est=3.544155124166011, details={'was_impossible': False}),
#  Prediction(uid=33, iid=1641, r_ui=5.0, est=3.971580940302922, details={'was_impossible': False}),
#  Prediction(uid=452, iid=3438, r_ui=4.0, est=4.065952360532412, details={'was_impossible': False}),
#  Prediction(uid=542, iid=1282, r_ui=4.0, est=3.631084920996691, details={'was_impossible': False}),
#  Prediction(uid=351, iid=3981, r_ui=3.5, est=2.8509167785221905, details={'was_impossible': False}),
#  Prediction(uid=325, iid=2204, r_ui=3.0, est=3.706710941074611, details={'was_impossible': False}),
#  Prediction(uid=249, iid=101142, r_ui=3.5, est=3.7401542945077892, details={'was_impossible': False}),
#  Prediction(uid=480, iid=27839, r_ui=2.5, est=2.5118932653314685, details={'was_impossible': False}),
#  Prediction(uid=599, iid=2761, r_ui=3.0, est=3.052547236323131, details={'was_impossible': False}),
#  Prediction(uid=140, iid=6947, r_ui=5.0, est=3.329755140131136, details={'was_impossible': False}),
#  Prediction(uid=50, iid=969, r_ui=3.5, est=3.165441303830411, details={'was_impossible': False}),
#  Prediction(uid=438, iid=2640, r_ui=4.0, est=3.3615820036503745, details={'was_impossible': False}),
#  Prediction(uid=599, iid=3243, r_ui=1.5, est=1.892142507696997, details={'was_impossible': False}),
#  Prediction(uid=580, iid=919, r_ui=2.0, est=3.69975879458459, details={'was_impossible': False}),
#  Prediction(uid=64, iid=6874, r_ui=4.0, est=4.403416586512063, details={'was_impossible': False}),
#  Prediction(uid=584, iid=539, r_ui=5.0, est=4.357363447067806, details={'was_impossible': False}),
#  Prediction(uid=89, iid=174681, r_ui=3.5, est=3.4729411334016365, details={'was_impossible': False}),
#  Prediction(uid=356, iid=1653, r_ui=4.5, est=4.1421712870116005, details={'was_impossible': False}),
#  Prediction(uid=602, iid=480, r_ui=4.0, est=3.7035771258472034, details={'was_impossible': False}),
#  Prediction(uid=606, iid=1380, r_ui=3.5, est=3.273002836856898, details={'was_impossible': False}),
#  Prediction(uid=351, iid=56941, r_ui=3.0, est=3.5251089258001325, details={'was_impossible': False}),
#  Prediction(uid=397, iid=4017, r_ui=4.0, est=3.4703912795784064, details={'was_impossible': False}),
#  Prediction(uid=599, iid=6932, r_ui=2.5, est=2.865114318321456, details={'was_impossible': False}),
#  Prediction(uid=401, iid=76093, r_ui=3.5, est=3.8995514748438396, details={'was_impossible': False}),
#  Prediction(uid=121, iid=225, r_ui=3.0, est=3.305879944808064, details={'was_impossible': False}),
#  Prediction(uid=393, iid=74458, r_ui=0.5, est=4.109304949578539, details={'was_impossible': False}),
#  Prediction(uid=117, iid=848, r_ui=3.0, est=3.1109873774136383, details={'was_impossible': False}),
#  Prediction(uid=586, iid=8368, r_ui=5.0, est=4.677278657749695, details={'was_impossible': False}),
#  Prediction(uid=483, iid=105325, r_ui=1.0, est=3.5097263092979283, details={'was_impossible': False}),
#  Prediction(uid=434, iid=588, r_ui=4.0, est=3.650495407694845, details={'was_impossible': False}),
#  Prediction(uid=356, iid=7122, r_ui=5.0, est=3.692532367941628, details={'was_impossible': False}),
#  Prediction(uid=402, iid=597, r_ui=4.0, est=4.1334599126801645, details={'was_impossible': False}),
#  Prediction(uid=414, iid=3157, r_ui=4.0, est=2.805834956361591, details={'was_impossible': False}),
#  Prediction(uid=61, iid=266, r_ui=4.0, est=3.369343992014943, details={'was_impossible': False}),
#  Prediction(uid=599, iid=32387, r_ui=3.5, est=2.9481487513043847, details={'was_impossible': False}),
#  Prediction(uid=336, iid=50, r_ui=5.0, est=4.580885607696826, details={'was_impossible': False}),
#  Prediction(uid=411, iid=160, r_ui=3.0, est=2.737305273194274, details={'was_impossible': False}),
#  Prediction(uid=517, iid=593, r_ui=3.0, est=2.8388801295570003, details={'was_impossible': False}),
#  Prediction(uid=369, iid=2948, r_ui=3.5, est=3.5706718860920454, details={'was_impossible': False}),
#  Prediction(uid=221, iid=5060, r_ui=4.5, est=4.329049233582671, details={'was_impossible': False}),
#  Prediction(uid=325, iid=3261, r_ui=2.0, est=3.4176220331093674, details={'was_impossible': False}),
#  Prediction(uid=376, iid=8961, r_ui=3.5, est=4.43282865815234, details={'was_impossible': False}),
#  Prediction(uid=356, iid=2321, r_ui=3.5, est=3.8588476583054163, details={'was_impossible': False}),
#  Prediction(uid=514, iid=2867, r_ui=4.0, est=3.145909290375883, details={'was_impossible': False}),
#  Prediction(uid=89, iid=32060, r_ui=3.0, est=3.4729411334016365, details={'was_impossible': False}),
#  Prediction(uid=608, iid=4367, r_ui=3.5, est=2.8823538336352645, details={'was_impossible': False}),
#  Prediction(uid=372, iid=34, r_ui=4.0, est=3.426377279564304, details={'was_impossible': False}),
#  Prediction(uid=100, iid=1290, r_ui=4.0, est=3.4274772914791676, details={'was_impossible': False}),
#  Prediction(uid=294, iid=725, r_ui=1.0, est=2.5791360423233254, details={'was_impossible': False}),
#  Prediction(uid=111, iid=6548, r_ui=3.5, est=2.9815629821483935, details={'was_impossible': False}),
#  Prediction(uid=610, iid=31696, r_ui=3.5, est=3.3372399438251845, details={'was_impossible': False}),
#  Prediction(uid=89, iid=99853, r_ui=4.0, est=3.4729411334016365, details={'was_impossible': False}),
#  Prediction(uid=599, iid=5903, r_ui=2.5, est=3.2023377887253184, details={'was_impossible': False}),
#  Prediction(uid=292, iid=1022, r_ui=3.0, est=3.303259119350768, details={'was_impossible': False}),
#  Prediction(uid=474, iid=45720, r_ui=3.5, est=3.4639180792460427, details={'was_impossible': False}),
#  Prediction(uid=274, iid=3552, r_ui=4.0, est=3.553201544612675, details={'was_impossible': False}),
#  Prediction(uid=6, iid=140, r_ui=3.0, est=3.4209346964155496, details={'was_impossible': False}),
#  Prediction(uid=18, iid=38061, r_ui=4.0, est=4.072865076555594, details={'was_impossible': False}),
#  Prediction(uid=240, iid=181, r_ui=3.0, est=3.6989016567483084, details={'was_impossible': False}),
#  Prediction(uid=438, iid=4367, r_ui=1.5, est=2.9427197574025725, details={'was_impossible': False}),
#  Prediction(uid=474, iid=4484, r_ui=3.5, est=3.4683558411406716, details={'was_impossible': False}),
#  Prediction(uid=318, iid=2542, r_ui=4.0, est=4.2106930502063005, details={'was_impossible': False}),
#  Prediction(uid=307, iid=66097, r_ui=4.5, est=2.067463081036615, details={'was_impossible': False}),
#  Prediction(uid=15, iid=780, r_ui=3.5, est=3.2712804574789205, details={'was_impossible': False}),
#  Prediction(uid=414, iid=1635, r_ui=4.0, est=3.5541688306376993, details={'was_impossible': False}),
#  Prediction(uid=105, iid=104069, r_ui=4.5, est=4.240300684002983, details={'was_impossible': False}),
#  Prediction(uid=599, iid=3007, r_ui=3.5, est=2.662970794755607, details={'was_impossible': False}),
#  Prediction(uid=359, iid=480, r_ui=4.0, est=3.2818858046962407, details={'was_impossible': False}),
#  Prediction(uid=177, iid=63853, r_ui=2.0, est=3.280596533465599, details={'was_impossible': False}),
#  Prediction(uid=247, iid=593, r_ui=4.0, est=4.222919236419831, details={'was_impossible': False}),
#  Prediction(uid=239, iid=2890, r_ui=4.0, est=3.9745457230845105, details={'was_impossible': False}),
#  Prediction(uid=84, iid=1136, r_ui=4.0, est=4.292233298863678, details={'was_impossible': False}),
#  Prediction(uid=307, iid=345, r_ui=3.5, est=3.1253121960308006, details={'was_impossible': False}),
#  Prediction(uid=68, iid=216, r_ui=3.5, est=3.036606961228214, details={'was_impossible': False}),
#  Prediction(uid=567, iid=1198, r_ui=2.5, est=3.7051378192247535, details={'was_impossible': False}),
#  Prediction(uid=95, iid=4901, r_ui=4.0, est=4.027967719815964, details={'was_impossible': False}),
#  Prediction(uid=600, iid=2115, r_ui=3.5, est=3.387902744832137, details={'was_impossible': False}),
#  Prediction(uid=534, iid=119145, r_ui=4.5, est=4.160073195412821, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1527, r_ui=4.0, est=3.8919028579099866, details={'was_impossible': False}),
#  Prediction(uid=590, iid=3362, r_ui=3.5, est=3.9131305717499902, details={'was_impossible': False}),
#  Prediction(uid=16, iid=50, r_ui=4.0, est=3.72682525263354, details={'was_impossible': False}),
#  Prediction(uid=608, iid=3578, r_ui=4.0, est=3.5909733461159616, details={'was_impossible': False}),
#  Prediction(uid=448, iid=88163, r_ui=3.5, est=3.621847367288109, details={'was_impossible': False}),
#  Prediction(uid=474, iid=1323, r_ui=2.0, est=3.150463724276845, details={'was_impossible': False}),
#  Prediction(uid=182, iid=44199, r_ui=3.0, est=3.5470734209398462, details={'was_impossible': False}),
#  Prediction(uid=284, iid=231, r_ui=4.0, est=3.5962304511156296, details={'was_impossible': False}),
#  Prediction(uid=34, iid=3948, r_ui=3.0, est=3.3243469797757395, details={'was_impossible': False}),
#  Prediction(uid=160, iid=2018, r_ui=5.0, est=1.9623590891119944, details={'was_impossible': False}),
#  Prediction(uid=448, iid=115216, r_ui=3.0, est=2.8581871533590233, details={'was_impossible': False}),
#  Prediction(uid=79, iid=3578, r_ui=2.0, est=4.467923226363272, details={'was_impossible': False}),
#  Prediction(uid=72, iid=150, r_ui=4.0, est=4.147870045897891, details={'was_impossible': False}),
#  Prediction(uid=357, iid=1213, r_ui=5.0, est=4.504735141338475, details={'was_impossible': False}),
#  Prediction(uid=414, iid=3489, r_ui=4.0, est=3.090920571177469, details={'was_impossible': False}),
#  Prediction(uid=282, iid=4816, r_ui=2.5, est=3.7588562138128028, details={'was_impossible': False}),
#  Prediction(uid=391, iid=4034, r_ui=2.0, est=3.568284390952134, details={'was_impossible': False}),
#  Prediction(uid=600, iid=480, r_ui=3.0, est=3.5498027822129785, details={'was_impossible': False}),
#  Prediction(uid=20, iid=3157, r_ui=3.0, est=3.1464657758770866, details={'was_impossible': False}),
#  Prediction(uid=606, iid=6564, r_ui=2.0, est=3.4290808687964818, details={'was_impossible': False}),
#  Prediction(uid=115, iid=2772, r_ui=1.0, est=3.7269295213433686, details={'was_impossible': False}),
#  Prediction(uid=372, iid=1352, r_ui=2.0, est=2.8520826104921673, details={'was_impossible': False}),
#  Prediction(uid=352, iid=1835, r_ui=3.0, est=3.506011608971952, details={'was_impossible': False}),
#  Prediction(uid=483, iid=57669, r_ui=4.5, est=4.297799836360974, details={'was_impossible': False}),
#  Prediction(uid=122, iid=3535, r_ui=5.0, est=4.550433770169126, details={'was_impossible': False}),
#  Prediction(uid=318, iid=2, r_ui=3.5, est=3.8307300218356115, details={'was_impossible': False}),
#  Prediction(uid=177, iid=3408, r_ui=4.0, est=3.692427543604336, details={'was_impossible': False}),
#  Prediction(uid=563, iid=72919, r_ui=3.0, est=3.297178581844382, details={'was_impossible': False}),
#  Prediction(uid=45, iid=1285, r_ui=3.0, est=3.9950312968166584, details={'was_impossible': False}),
#  Prediction(uid=483, iid=68157, r_ui=4.0, est=4.090014706038742, details={'was_impossible': False}),
#  Prediction(uid=414, iid=653, r_ui=3.0, est=2.74591405760539, details={'was_impossible': False}),
#  Prediction(uid=271, iid=4466, r_ui=3.0, est=3.0821079774642306, details={'was_impossible': False}),
#  Prediction(uid=332, iid=60684, r_ui=4.0, est=3.8247481580632328, details={'was_impossible': False}),
#  Prediction(uid=357, iid=39, r_ui=4.5, est=3.906918937699418, details={'was_impossible': False}),
#  Prediction(uid=63, iid=858, r_ui=4.0, est=3.839871464819912, details={'was_impossible': False}),
#  Prediction(uid=339, iid=90345, r_ui=4.5, est=3.71093051335114, details={'was_impossible': False}),
#  Prediction(uid=414, iid=3037, r_ui=4.0, est=4.119811737069043, details={'was_impossible': False}),
#  Prediction(uid=520, iid=48780, r_ui=3.5, est=4.305860222169187, details={'was_impossible': False}),
#  Prediction(uid=460, iid=4886, r_ui=4.0, est=4.191408020912182, details={'was_impossible': False}),
#  Prediction(uid=514, iid=3877, r_ui=1.0, est=2.6380193861647596, details={'was_impossible': False}),
#  Prediction(uid=20, iid=4299, r_ui=3.5, est=3.327624402974867, details={'was_impossible': False}),
#  Prediction(uid=28, iid=61986, r_ui=3.0, est=2.8514544099042727, details={'was_impossible': False}),
#  Prediction(uid=288, iid=56339, r_ui=3.5, est=3.130734679782206, details={'was_impossible': False}),
#  Prediction(uid=28, iid=6957, r_ui=3.0, est=3.033632455454958, details={'was_impossible': False}),
#  Prediction(uid=415, iid=2858, r_ui=3.5, est=4.650565249828229, details={'was_impossible': False}),
#  Prediction(uid=432, iid=5989, r_ui=4.0, est=3.639563095600174, details={'was_impossible': False}),
#  Prediction(uid=68, iid=508, r_ui=3.0, est=3.4312948061336064, details={'was_impossible': False}),
#  Prediction(uid=525, iid=133419, r_ui=2.5, est=3.57171503571122, details={'was_impossible': False}),
#  Prediction(uid=38, iid=48, r_ui=3.0, est=2.587274171782158, details={'was_impossible': False}),
#  Prediction(uid=599, iid=6267, r_ui=2.0, est=2.6276162334631468, details={'was_impossible': False}),
#  Prediction(uid=249, iid=53000, r_ui=3.5, est=3.809086714758803, details={'was_impossible': False}),
#  Prediction(uid=212, iid=27773, r_ui=4.5, est=3.755629086686957, details={'was_impossible': False}),
#  Prediction(uid=582, iid=91658, r_ui=4.0, est=3.836200077321827, details={'was_impossible': False}),
#  Prediction(uid=518, iid=1597, r_ui=3.5, est=3.1485809402440577, details={'was_impossible': False}),
#  Prediction(uid=133, iid=50, r_ui=3.0, est=3.4995377360875146, details={'was_impossible': False}),
#  Prediction(uid=414, iid=1647, r_ui=3.0, est=3.1989766224829146, details={'was_impossible': False}),
#  Prediction(uid=249, iid=87306, r_ui=4.0, est=3.751403216648982, details={'was_impossible': False}),
#  Prediction(uid=305, iid=8874, r_ui=4.0, est=4.243469345000061, details={'was_impossible': False}),
#  Prediction(uid=332, iid=8949, r_ui=4.0, est=3.8475269093632627, details={'was_impossible': False}),
#  Prediction(uid=522, iid=102445, r_ui=4.5, est=3.626489622712935, details={'was_impossible': False}),
#  Prediction(uid=288, iid=6305, r_ui=3.5, est=3.4234971864062875, details={'was_impossible': False}),
#  Prediction(uid=484, iid=86833, r_ui=4.0, est=3.9955379427263416, details={'was_impossible': False}),
#  Prediction(uid=177, iid=111921, r_ui=5.0, est=3.2786967340043978, details={'was_impossible': False}),
#  Prediction(uid=372, iid=538, r_ui=3.0, est=3.311905220552188, details={'was_impossible': False}),
#  Prediction(uid=109, iid=151, r_ui=4.0, est=3.3046684652516936, details={'was_impossible': False}),
#  Prediction(uid=182, iid=4642, r_ui=4.5, est=3.917695579978617, details={'was_impossible': False}),
#  Prediction(uid=64, iid=5673, r_ui=5.0, est=3.991530468459115, details={'was_impossible': False}),
#  Prediction(uid=382, iid=2643, r_ui=2.0, est=2.294213977112531, details={'was_impossible': False}),
#  Prediction(uid=217, iid=1614, r_ui=3.0, est=2.5135632918476327, details={'was_impossible': False}),
#  Prediction(uid=428, iid=5378, r_ui=3.5, est=2.445301362914325, details={'was_impossible': False}),
#  Prediction(uid=76, iid=111, r_ui=3.0, est=3.4883430322030486, details={'was_impossible': False}),
#  Prediction(uid=201, iid=1732, r_ui=2.0, est=4.602091705030846, details={'was_impossible': False}),
#  Prediction(uid=490, iid=1089, r_ui=4.0, est=3.3101200916646807, details={'was_impossible': False}),
#  Prediction(uid=129, iid=185, r_ui=3.5, est=3.621372981509759, details={'was_impossible': False}),
#  Prediction(uid=596, iid=1377, r_ui=3.0, est=2.8728866716613064, details={'was_impossible': False}),
#  Prediction(uid=602, iid=16, r_ui=3.0, est=4.054101910155514, details={'was_impossible': False}),
#  Prediction(uid=280, iid=919, r_ui=3.5, est=4.33801180054056, details={'was_impossible': False}),
#  Prediction(uid=482, iid=1517, r_ui=4.0, est=3.8200653254033416, details={'was_impossible': False}),
#  Prediction(uid=307, iid=36708, r_ui=4.0, est=2.8644432018941304, details={'was_impossible': False}),
#  Prediction(uid=606, iid=5712, r_ui=3.5, est=3.359132902060884, details={'was_impossible': False}),
#  Prediction(uid=80, iid=103688, r_ui=4.0, est=4.415889599511851, details={'was_impossible': False}),
#  Prediction(uid=599, iid=2028, r_ui=3.5, est=3.626922746904218, details={'was_impossible': False}),
#  Prediction(uid=64, iid=364, r_ui=4.0, est=4.006984625117993, details={'was_impossible': False}),
#  Prediction(uid=236, iid=2718, r_ui=3.0, est=3.873110911730213, details={'was_impossible': False}),
#  Prediction(uid=292, iid=68358, r_ui=4.0, est=3.54375680146756, details={'was_impossible': False}),
#  Prediction(uid=216, iid=927, r_ui=4.0, est=3.3840157747088737, details={'was_impossible': False}),
#  Prediction(uid=414, iid=2403, r_ui=4.0, est=3.616606925839823, details={'was_impossible': False}),
#  Prediction(uid=214, iid=1356, r_ui=3.0, est=3.3508730470588555, details={'was_impossible': False}),
#  Prediction(uid=164, iid=1291, r_ui=5.0, est=4.486502648137348, details={'was_impossible': False}),
#  Prediction(uid=108, iid=156, r_ui=4.0, est=3.821696200301877, details={'was_impossible': False}),
#  Prediction(uid=19, iid=2328, r_ui=2.0, est=2.153310423913409, details={'was_impossible': False}),
#  Prediction(uid=292, iid=8368, r_ui=4.0, est=3.7525332871713215, details={'was_impossible': False}),
#  Prediction(uid=50, iid=175743, r_ui=3.0, est=2.595254163426114, details={'was_impossible': False}),
#  Prediction(uid=510, iid=104, r_ui=3.0, est=2.90165186352657, details={'was_impossible': False}),
#  Prediction(uid=603, iid=3787, r_ui=3.0, est=4.0075070663650205, details={'was_impossible': False}),
#  Prediction(uid=249, iid=356, r_ui=4.5, est=4.56776396395561, details={'was_impossible': False}),
#  Prediction(uid=230, iid=2959, r_ui=3.0, est=3.3132065401609987, details={'was_impossible': False}),
#  Prediction(uid=559, iid=474, r_ui=3.0, est=3.6761937303941905, details={'was_impossible': False}),
#  Prediction(uid=217, iid=1686, r_ui=3.0, est=3.089032134555027, details={'was_impossible': False}),
#  Prediction(uid=400, iid=44199, r_ui=5.0, est=4.155779093461802, details={'was_impossible': False}),
#  Prediction(uid=21, iid=3578, r_ui=2.5, est=3.4652783048777094, details={'was_impossible': False}),
#  Prediction(uid=561, iid=7007, r_ui=3.0, est=3.3993259483727614, details={'was_impossible': False}),
#  Prediction(uid=525, iid=48394, r_ui=4.0, est=3.7197850476866448, details={'was_impossible': False}),
#  Prediction(uid=356, iid=61132, r_ui=3.5, est=3.855397335261697, details={'was_impossible': False}),
#  Prediction(uid=414, iid=5902, r_ui=5.0, est=4.0339137028201995, details={'was_impossible': False}),
#  Prediction(uid=288, iid=8665, r_ui=3.5, est=3.2933075127070692, details={'was_impossible': False}),
#  Prediction(uid=368, iid=1729, r_ui=3.0, est=3.312464837389408, details={'was_impossible': False}),
#  Prediction(uid=599, iid=104837, r_ui=2.0, est=2.6276162334631468, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1994, r_ui=2.5, est=2.959504015370621, details={'was_impossible': False}),
#  Prediction(uid=577, iid=1220, r_ui=4.0, est=3.6009742804236295, details={'was_impossible': False}),
#  Prediction(uid=232, iid=4388, r_ui=3.0, est=2.594913602349129, details={'was_impossible': False}),
#  Prediction(uid=599, iid=3973, r_ui=0.5, est=2.1505215664890884, details={'was_impossible': False}),
#  Prediction(uid=409, iid=2352, r_ui=4.0, est=4.033931004299943, details={'was_impossible': False}),
#  Prediction(uid=387, iid=432, r_ui=0.5, est=2.1780639354730003, details={'was_impossible': False}),
#  Prediction(uid=274, iid=2085, r_ui=3.5, est=3.0938073508777015, details={'was_impossible': False}),
#  Prediction(uid=455, iid=593, r_ui=5.0, est=4.090710035319, details={'was_impossible': False}),
#  Prediction(uid=241, iid=2959, r_ui=3.0, est=4.292797548532722, details={'was_impossible': False}),
#  Prediction(uid=567, iid=106766, r_ui=4.0, est=2.329093228803356, details={'was_impossible': False}),
#  Prediction(uid=186, iid=899, r_ui=4.0, est=4.6037156210064865, details={'was_impossible': False}),
#  Prediction(uid=141, iid=7153, r_ui=4.0, est=4.073905033874991, details={'was_impossible': False}),
#  Prediction(uid=280, iid=3489, r_ui=4.0, est=3.9274922552713116, details={'was_impossible': False}),
#  Prediction(uid=74, iid=55247, r_ui=4.5, est=4.338887987264689, details={'was_impossible': False}),
#  Prediction(uid=488, iid=1197, r_ui=5.0, est=3.8740098097939484, details={'was_impossible': False}),
#  Prediction(uid=274, iid=4553, r_ui=4.5, est=3.324901988881709, details={'was_impossible': False}),
#  Prediction(uid=7, iid=3869, r_ui=5.0, est=3.0180882314602235, details={'was_impossible': False}),
#  Prediction(uid=369, iid=45728, r_ui=3.5, est=3.628280880501746, details={'was_impossible': False}),
#  Prediction(uid=414, iid=48738, r_ui=4.0, est=3.6140367264940867, details={'was_impossible': False}),
#  Prediction(uid=232, iid=37477, r_ui=2.5, est=3.2441569617828856, details={'was_impossible': False}),
#  Prediction(uid=45, iid=2841, r_ui=4.0, est=3.9416463906327, details={'was_impossible': False}),
#  Prediction(uid=610, iid=60333, r_ui=5.0, est=3.622148353593951, details={'was_impossible': False}),
#  Prediction(uid=599, iid=6996, r_ui=1.5, est=2.1839753807042492, details={'was_impossible': False}),
#  Prediction(uid=169, iid=2321, r_ui=4.5, est=4.1611220485994584, details={'was_impossible': False}),
#  Prediction(uid=66, iid=1210, r_ui=3.0, est=4.359369980381586, details={'was_impossible': False}),
#  Prediction(uid=292, iid=103253, r_ui=4.0, est=2.7938115719000445, details={'was_impossible': False}),
#  Prediction(uid=182, iid=81, r_ui=3.5, est=3.463296555682173, details={'was_impossible': False}),
#  Prediction(uid=474, iid=4860, r_ui=2.0, est=3.2312679793844232, details={'was_impossible': False}),
#  Prediction(uid=474, iid=5791, r_ui=4.0, est=3.670241766987454, details={'was_impossible': False}),
#  Prediction(uid=62, iid=1196, r_ui=4.5, est=4.4612464671101755, details={'was_impossible': False}),
#  Prediction(uid=474, iid=7086, r_ui=3.5, est=3.2312679793844232, details={'was_impossible': False}),
#  Prediction(uid=586, iid=68157, r_ui=4.0, est=4.7993989762390585, details={'was_impossible': False}),
#  Prediction(uid=600, iid=2167, r_ui=1.5, est=2.3560146977028738, details={'was_impossible': False}),
#  Prediction(uid=483, iid=253, r_ui=3.5, est=3.5655012089332168, details={'was_impossible': False}),
#  Prediction(uid=233, iid=109374, r_ui=3.0, est=3.2843971670858823, details={'was_impossible': False}),
#  Prediction(uid=547, iid=1394, r_ui=5.0, est=4.523886468477536, details={'was_impossible': False}),
#  Prediction(uid=555, iid=196, r_ui=3.0, est=2.6264011952604656, details={'was_impossible': False}),
#  Prediction(uid=310, iid=2372, r_ui=2.0, est=2.82720877885766, details={'was_impossible': False}),
#  Prediction(uid=605, iid=1608, r_ui=3.0, est=3.3519310637528803, details={'was_impossible': False}),
#  Prediction(uid=317, iid=77561, r_ui=3.0, est=3.3401036199976484, details={'was_impossible': False}),
#  Prediction(uid=474, iid=262, r_ui=4.0, est=3.437095618493609, details={'was_impossible': False}),
#  Prediction(uid=514, iid=3039, r_ui=3.5, est=3.3630412594449326, details={'was_impossible': False}),
#  Prediction(uid=28, iid=7841, r_ui=4.5, est=2.788583499627386, details={'was_impossible': False}),
#  Prediction(uid=249, iid=96861, r_ui=3.5, est=3.363450546484136, details={'was_impossible': False}),
#  Prediction(uid=91, iid=376, r_ui=2.5, est=2.929139213129609, details={'was_impossible': False}),
#  Prediction(uid=234, iid=3479, r_ui=3.0, est=3.435923894796863, details={'was_impossible': False}),
#  Prediction(uid=122, iid=1748, r_ui=5.0, est=4.640920422225156, details={'was_impossible': False}),
#  Prediction(uid=288, iid=2135, r_ui=3.0, est=3.4162572742755426, details={'was_impossible': False}),
#  Prediction(uid=20, iid=3977, r_ui=3.5, est=2.7304553536046376, details={'was_impossible': False}),
#  Prediction(uid=343, iid=1213, r_ui=5.0, est=4.509637634494602, details={'was_impossible': False}),
#  Prediction(uid=414, iid=1278, r_ui=4.0, est=4.475812487282263, details={'was_impossible': False}),
#  Prediction(uid=249, iid=84772, r_ui=4.0, est=3.588230664872138, details={'was_impossible': False}),
#  Prediction(uid=474, iid=316, r_ui=3.5, est=3.081453926235321, details={'was_impossible': False}),
#  Prediction(uid=328, iid=68157, r_ui=4.5, est=3.240766600552034, details={'was_impossible': False}),
#  Prediction(uid=400, iid=1198, r_ui=4.5, est=4.614884469271082, details={'was_impossible': False}),
#  Prediction(uid=177, iid=1408, r_ui=2.5, est=3.5860562895291297, details={'was_impossible': False}),
#  Prediction(uid=25, iid=187593, r_ui=5.0, est=4.269379088624296, details={'was_impossible': False}),
#  Prediction(uid=570, iid=1270, r_ui=4.0, est=3.869657018708685, details={'was_impossible': False}),
#  Prediction(uid=393, iid=96079, r_ui=5.0, est=4.094571142109696, details={'was_impossible': False}),
#  Prediction(uid=414, iid=48412, r_ui=2.5, est=3.1180958405688584, details={'was_impossible': False}),
#  Prediction(uid=483, iid=2174, r_ui=4.0, est=3.115375795248948, details={'was_impossible': False}),
#  Prediction(uid=549, iid=1291, r_ui=3.0, est=3.6270142492015776, details={'was_impossible': False}),
#  Prediction(uid=219, iid=1552, r_ui=3.0, est=2.883150850580604, details={'was_impossible': False}),
#  Prediction(uid=530, iid=161, r_ui=3.0, est=3.898226132745119, details={'was_impossible': False}),
#  Prediction(uid=593, iid=1196, r_ui=5.0, est=3.5896210533326665, details={'was_impossible': False}),
#  Prediction(uid=544, iid=116, r_ui=5.0, est=3.9097351437325787, details={'was_impossible': False}),
#  Prediction(uid=385, iid=249, r_ui=3.0, est=3.7000933117978136, details={'was_impossible': False}),
#  Prediction(uid=599, iid=3984, r_ui=2.5, est=2.8454381132785223, details={'was_impossible': False}),
#  Prediction(uid=119, iid=5989, r_ui=4.5, est=4.5337335835081625, details={'was_impossible': False}),
#  Prediction(uid=74, iid=6591, r_ui=5.0, est=4.25146200238487, details={'was_impossible': False}),
#  Prediction(uid=382, iid=4896, r_ui=4.5, est=3.6364725041370125, details={'was_impossible': False}),
#  Prediction(uid=594, iid=1923, r_ui=4.0, est=4.338084881776702, details={'was_impossible': False}),
#  Prediction(uid=597, iid=610, r_ui=4.0, est=3.6816516362597063, details={'was_impossible': False}),
#  Prediction(uid=592, iid=6, r_ui=3.0, est=3.9719714052042487, details={'was_impossible': False}),
#  Prediction(uid=503, iid=2762, r_ui=3.0, est=3.5344839830546624, details={'was_impossible': False}),
#  Prediction(uid=45, iid=2528, r_ui=4.0, est=3.5541605109207044, details={'was_impossible': False}),
#  Prediction(uid=532, iid=707, r_ui=4.0, est=3.4320368556302334, details={'was_impossible': False}),
#  Prediction(uid=64, iid=2700, r_ui=4.5, est=4.162876513160604, details={'was_impossible': False}),
#  Prediction(uid=240, iid=160, r_ui=4.0, est=3.693552397559523, details={'was_impossible': False}),
#  Prediction(uid=599, iid=143355, r_ui=2.0, est=2.723794573154786, details={'was_impossible': False}),
#  Prediction(uid=274, iid=30825, r_ui=2.5, est=3.052160748355997, details={'was_impossible': False}),
#  Prediction(uid=28, iid=61132, r_ui=2.0, est=3.1674726985625035, details={'was_impossible': False}),
#  Prediction(uid=249, iid=102686, r_ui=3.5, est=3.833864108056629, details={'was_impossible': False}),
#  Prediction(uid=198, iid=24, r_ui=4.0, est=2.8619817819157465, details={'was_impossible': False}),
#  Prediction(uid=63, iid=81229, r_ui=4.0, est=3.345932739487959, details={'was_impossible': False}),
#  Prediction(uid=328, iid=8636, r_ui=3.5, est=3.8301014305351497, details={'was_impossible': False}),
#  Prediction(uid=298, iid=54995, r_ui=2.5, est=2.7705854514517907, details={'was_impossible': False}),
#  Prediction(uid=45, iid=3249, r_ui=3.0, est=3.747953158019851, details={'was_impossible': False}),
#  Prediction(uid=111, iid=168248, r_ui=4.0, est=3.019156121392901, details={'was_impossible': False}),
#  Prediction(uid=222, iid=1089, r_ui=4.0, est=3.7924227923532614, details={'was_impossible': False}),
#  Prediction(uid=31, iid=733, r_ui=5.0, est=3.6754809374641466, details={'was_impossible': False}),
#  Prediction(uid=603, iid=1321, r_ui=3.0, est=3.980456131469706, details={'was_impossible': False}),
#  Prediction(uid=135, iid=3996, r_ui=5.0, est=3.5851383537828037, details={'was_impossible': False}),
#  Prediction(uid=105, iid=34048, r_ui=3.5, est=3.6017270114822297, details={'was_impossible': False}),
#  Prediction(uid=604, iid=177, r_ui=4.0, est=3.1672845466441735, details={'was_impossible': False}),
#  Prediction(uid=438, iid=8644, r_ui=4.0, est=3.1693921459896055, details={'was_impossible': False}),
#  Prediction(uid=177, iid=1025, r_ui=4.0, est=3.56579826944019, details={'was_impossible': False}),
#  Prediction(uid=590, iid=898, r_ui=4.0, est=4.201739749407074, details={'was_impossible': False}),
#  Prediction(uid=380, iid=4728, r_ui=4.0, est=3.6541033227749624, details={'was_impossible': False}),
#  Prediction(uid=249, iid=134130, r_ui=4.0, est=4.175077166794119, details={'was_impossible': False}),
#  Prediction(uid=448, iid=3826, r_ui=2.0, est=1.7967765223680088, details={'was_impossible': False}),
#  Prediction(uid=600, iid=2640, r_ui=3.5, est=2.9389755537799207, details={'was_impossible': False}),
#  Prediction(uid=522, iid=81834, r_ui=3.5, est=3.794171593766439, details={'was_impossible': False}),
#  Prediction(uid=453, iid=3882, r_ui=4.0, est=3.6888379913354306, details={'was_impossible': False}),
#  Prediction(uid=187, iid=27397, r_ui=5.0, est=3.698636665841917, details={'was_impossible': False}),
#  Prediction(uid=430, iid=6365, r_ui=4.5, est=3.3925024461831836, details={'was_impossible': False}),
#  Prediction(uid=199, iid=2890, r_ui=4.0, est=3.341186801426881, details={'was_impossible': False}),
#  Prediction(uid=414, iid=1732, r_ui=5.0, est=4.140852058871062, details={'was_impossible': False}),
#  Prediction(uid=596, iid=27020, r_ui=3.5, est=3.362134421171815, details={'was_impossible': False}),
#  Prediction(uid=220, iid=1200, r_ui=5.0, est=3.958400669375837, details={'was_impossible': False}),
#  Prediction(uid=156, iid=356, r_ui=3.0, est=4.347285508505181, details={'was_impossible': False}),
#  Prediction(uid=600, iid=30749, r_ui=2.0, est=3.646067244453492, details={'was_impossible': False}),
#  Prediction(uid=314, iid=648, r_ui=3.0, est=3.1393266887575875, details={'was_impossible': False}),
#  Prediction(uid=332, iid=1380, r_ui=3.5, est=3.311235150095449, details={'was_impossible': False}),
#  Prediction(uid=552, iid=2993, r_ui=3.0, est=3.0197941915757567, details={'was_impossible': False}),
#  Prediction(uid=438, iid=6196, r_ui=3.0, est=3.4366293978782605, details={'was_impossible': False}),
#  Prediction(uid=503, iid=593, r_ui=3.5, est=3.8993851969138307, details={'was_impossible': False}),
#  Prediction(uid=599, iid=2243, r_ui=2.5, est=2.4939992408582743, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1947, r_ui=5.0, est=3.3077823493527787, details={'was_impossible': False}),
#  Prediction(uid=282, iid=16, r_ui=4.0, est=4.358021788772675, details={'was_impossible': False}),
#  Prediction(uid=387, iid=2183, r_ui=4.0, est=3.3492991580953784, details={'was_impossible': False}),
#  Prediction(uid=221, iid=6711, r_ui=5.0, est=4.421745451063624, details={'was_impossible': False}),
#  Prediction(uid=414, iid=2889, r_ui=4.0, est=3.940684515779515, details={'was_impossible': False}),
#  Prediction(uid=474, iid=5502, r_ui=4.5, est=3.000379715431502, details={'was_impossible': False}),
#  Prediction(uid=226, iid=216, r_ui=5.0, est=3.652173649458187, details={'was_impossible': False}),
#  Prediction(uid=239, iid=4718, r_ui=3.5, est=3.345012178368775, details={'was_impossible': False}),
#  Prediction(uid=425, iid=2502, r_ui=4.0, est=4.024486181782865, details={'was_impossible': False}),
#  Prediction(uid=178, iid=161, r_ui=4.5, est=4.076352037930603, details={'was_impossible': False}),
#  Prediction(uid=288, iid=5543, r_ui=2.0, est=2.946109280593823, details={'was_impossible': False}),
#  Prediction(uid=69, iid=1258, r_ui=5.0, est=4.696153266264718, details={'was_impossible': False}),
#  Prediction(uid=561, iid=30793, r_ui=2.5, est=2.8427619609109422, details={'was_impossible': False}),
#  Prediction(uid=480, iid=3081, r_ui=3.5, est=3.2245811306487973, details={'was_impossible': False}),
#  Prediction(uid=474, iid=4024, r_ui=2.5, est=3.0062661028917756, details={'was_impossible': False}),
#  Prediction(uid=610, iid=102070, r_ui=3.0, est=3.5805714380866847, details={'was_impossible': False}),
#  Prediction(uid=560, iid=3481, r_ui=3.0, est=3.6078705507242543, details={'was_impossible': False}),
#  Prediction(uid=68, iid=66198, r_ui=3.0, est=2.898842870667176, details={'was_impossible': False}),
#  Prediction(uid=45, iid=2858, r_ui=5.0, est=4.2193218143523765, details={'was_impossible': False}),
#  Prediction(uid=298, iid=1466, r_ui=2.0, est=2.583897968958253, details={'was_impossible': False}),
#  Prediction(uid=21, iid=733, r_ui=3.5, est=3.0409260894311863, details={'was_impossible': False}),
#  Prediction(uid=64, iid=4369, r_ui=2.5, est=3.123442901799209, details={'was_impossible': False}),
#  Prediction(uid=417, iid=1682, r_ui=5.0, est=4.49511763381678, details={'was_impossible': False}),
#  Prediction(uid=279, iid=5903, r_ui=3.0, est=3.564435992450077, details={'was_impossible': False}),
#  Prediction(uid=104, iid=5013, r_ui=3.5, est=3.5717182894025337, details={'was_impossible': False}),
#  Prediction(uid=68, iid=79702, r_ui=4.0, est=3.450624128581144, details={'was_impossible': False}),
#  Prediction(uid=237, iid=44191, r_ui=4.0, est=3.8126665894686007, details={'was_impossible': False}),
#  Prediction(uid=387, iid=5570, r_ui=3.0, est=3.2940331511767047, details={'was_impossible': False}),
#  Prediction(uid=160, iid=4993, r_ui=2.0, est=3.295358668004429, details={'was_impossible': False}),
#  Prediction(uid=68, iid=2713, r_ui=3.0, est=2.857210814508848, details={'was_impossible': False}),
#  Prediction(uid=489, iid=3556, r_ui=3.0, est=2.8154214877697843, details={'was_impossible': False}),
#  Prediction(uid=18, iid=161582, r_ui=4.0, est=3.671162454453609, details={'was_impossible': False}),
#  Prediction(uid=465, iid=1769, r_ui=4.0, est=3.546484625088546, details={'was_impossible': False}),
#  Prediction(uid=307, iid=4995, r_ui=3.0, est=3.6938984439083438, details={'was_impossible': False}),
#  Prediction(uid=427, iid=1584, r_ui=3.0, est=3.1273323617982944, details={'was_impossible': False}),
#  Prediction(uid=369, iid=778, r_ui=4.0, est=3.9009841918257355, details={'was_impossible': False}),
# ...
#  Prediction(uid=610, iid=1953, r_ui=5.0, est=4.322907929209384, details={'was_impossible': False}),
#  Prediction(uid=448, iid=110297, r_ui=3.0, est=3.429620315228151, details={'was_impossible': False}),
#  Prediction(uid=570, iid=4878, r_ui=4.5, est=3.792338920963311, details={'was_impossible': False}),
#  Prediction(uid=228, iid=610, r_ui=3.0, est=3.7511873613274376, details={'was_impossible': False}),
#  Prediction(uid=380, iid=5459, r_ui=4.0, est=3.0051279584875146, details={'was_impossible': False}),
#  Prediction(uid=104, iid=52975, r_ui=4.0, est=3.4839069761171975, details={'was_impossible': False}),
#  Prediction(uid=436, iid=437, r_ui=3.0, est=2.621503995250572, details={'was_impossible': False}),
#  Prediction(uid=395, iid=597, r_ui=4.0, est=3.0248555169065137, details={'was_impossible': False}),
#  Prediction(uid=414, iid=2082, r_ui=2.0, est=2.637315811898865, details={'was_impossible': False}),
#  Prediction(uid=382, iid=339, r_ui=3.5, est=3.361660076682939, details={'was_impossible': False}),
#  Prediction(uid=33, iid=2762, r_ui=4.0, est=4.079474748108186, details={'was_impossible': False}),
#  Prediction(uid=517, iid=17, r_ui=0.5, est=2.7998129485895253, details={'was_impossible': False}),
#  Prediction(uid=477, iid=79132, r_ui=4.5, est=4.347059347240015, details={'was_impossible': False}),
#  Prediction(uid=599, iid=20, r_ui=1.5, est=2.0091162476275675, details={'was_impossible': False}),
#  Prediction(uid=488, iid=5995, r_ui=4.5, est=3.9783468058680582, details={'was_impossible': False}),
#  Prediction(uid=382, iid=2424, r_ui=3.5, est=2.9033118668219826, details={'was_impossible': False}),
#  Prediction(uid=169, iid=2710, r_ui=4.0, est=3.699191222740936, details={'was_impossible': False}),
#  Prediction(uid=167, iid=4980, r_ui=3.0, est=3.2649606626263177, details={'was_impossible': False}),
#  Prediction(uid=3, iid=26409, r_ui=4.5, est=2.3782330968902063, details={'was_impossible': False}),
#  Prediction(uid=374, iid=344, r_ui=4.0, est=3.2114761467482973, details={'was_impossible': False}),
#  Prediction(uid=600, iid=2340, r_ui=3.5, est=2.6969295991697098, details={'was_impossible': False}),
#  Prediction(uid=442, iid=524, r_ui=2.0, est=1.9383435281425831, details={'was_impossible': False}),
#  Prediction(uid=477, iid=337, r_ui=4.0, est=3.8377801296665277, details={'was_impossible': False}),
#  Prediction(uid=525, iid=81564, r_ui=3.5, est=3.4559064690248027, details={'was_impossible': False}),
#  Prediction(uid=89, iid=62155, r_ui=3.5, est=3.4359585942370914, details={'was_impossible': False}),
#  Prediction(uid=328, iid=1961, r_ui=2.0, est=3.250628736834302, details={'was_impossible': False}),
#  Prediction(uid=28, iid=7123, r_ui=3.0, est=2.8627012109778214, details={'was_impossible': False}),
#  Prediction(uid=30, iid=96821, r_ui=5.0, est=4.414708782261447, details={'was_impossible': False}),
#  Prediction(uid=498, iid=454, r_ui=5.0, est=3.7886840956696886, details={'was_impossible': False}),
#  Prediction(uid=123, iid=115617, r_ui=3.5, est=3.9164049712049294, details={'was_impossible': False}),
#  Prediction(uid=160, iid=1975, r_ui=1.0, est=2.496077830846422, details={'was_impossible': False}),
#  Prediction(uid=186, iid=908, r_ui=4.0, est=4.559703070479359, details={'was_impossible': False}),
#  Prediction(uid=414, iid=140715, r_ui=4.0, est=3.5592414237853043, details={'was_impossible': False}),
#  Prediction(uid=232, iid=5679, r_ui=2.5, est=3.2027872581860573, details={'was_impossible': False}),
#  Prediction(uid=8, iid=380, r_ui=5.0, est=3.314484046301629, details={'was_impossible': False}),
#  Prediction(uid=610, iid=82667, r_ui=4.0, est=3.756707876541481, details={'was_impossible': False}),
#  Prediction(uid=584, iid=367, r_ui=3.0, est=3.921532683809326, details={'was_impossible': False}),
#  Prediction(uid=113, iid=2791, r_ui=1.0, est=3.7367174510170056, details={'was_impossible': False}),
#  Prediction(uid=483, iid=88140, r_ui=3.0, est=3.498152149695118, details={'was_impossible': False}),
#  Prediction(uid=104, iid=2485, r_ui=3.0, est=2.8623495525674096, details={'was_impossible': False}),
#  Prediction(uid=448, iid=2717, r_ui=3.0, est=2.404214218580531, details={'was_impossible': False}),
#  Prediction(uid=352, iid=1222, r_ui=4.0, est=4.487277534929214, details={'was_impossible': False}),
#  Prediction(uid=125, iid=164179, r_ui=3.5, est=4.021717812914144, details={'was_impossible': False}),
#  Prediction(uid=469, iid=3681, r_ui=5.0, est=4.172498850902922, details={'was_impossible': False}),
#  Prediction(uid=104, iid=80584, r_ui=4.0, est=3.414078138183847, details={'was_impossible': False}),
#  Prediction(uid=95, iid=741, r_ui=5.0, est=4.247055097530257, details={'was_impossible': False}),
#  Prediction(uid=50, iid=139644, r_ui=3.0, est=2.8420089607445007, details={'was_impossible': False}),
#  Prediction(uid=380, iid=7387, r_ui=5.0, est=4.147404970357391, details={'was_impossible': False}),
#  Prediction(uid=522, iid=68194, r_ui=4.5, est=3.470092814558576, details={'was_impossible': False}),
#  Prediction(uid=391, iid=296, r_ui=5.0, est=4.3663696625434305, details={'was_impossible': False}),
#  Prediction(uid=21, iid=2052, r_ui=3.0, est=3.354035488128933, details={'was_impossible': False}),
#  Prediction(uid=274, iid=3265, r_ui=3.5, est=3.6844720475108788, details={'was_impossible': False}),
#  Prediction(uid=19, iid=2478, r_ui=2.0, est=2.781553585554616, details={'was_impossible': False}),
#  Prediction(uid=141, iid=4226, r_ui=3.0, est=3.9217032540874186, details={'was_impossible': False}),
#  Prediction(uid=57, iid=1407, r_ui=3.0, est=3.201993103047828, details={'was_impossible': False}),
#  Prediction(uid=432, iid=2676, r_ui=4.5, est=3.400670524113427, details={'was_impossible': False}),
#  Prediction(uid=561, iid=3948, r_ui=2.5, est=3.266566060321821, details={'was_impossible': False}),
#  Prediction(uid=84, iid=378, r_ui=3.0, est=3.5262396514380714, details={'was_impossible': False}),
#  Prediction(uid=140, iid=3983, r_ui=3.0, est=3.692173317639587, details={'was_impossible': False}),
#  Prediction(uid=546, iid=480, r_ui=4.0, est=3.381369158976021, details={'was_impossible': False}),
#  Prediction(uid=212, iid=93838, r_ui=4.0, est=3.56662539724791, details={'was_impossible': False}),
#  Prediction(uid=221, iid=34048, r_ui=2.5, est=3.5485785327340746, details={'was_impossible': False}),
#  Prediction(uid=198, iid=3894, r_ui=4.0, est=3.2969028714090074, details={'was_impossible': False}),
#  Prediction(uid=606, iid=5812, r_ui=3.5, est=3.916873026758778, details={'was_impossible': False}),
#  Prediction(uid=600, iid=662, r_ui=1.0, est=2.533647020491938, details={'was_impossible': False}),
#  Prediction(uid=313, iid=442, r_ui=4.0, est=3.0725617031258596, details={'was_impossible': False}),
#  Prediction(uid=382, iid=26764, r_ui=0.5, est=3.465299904320967, details={'was_impossible': False}),
#  Prediction(uid=474, iid=4709, r_ui=2.5, est=3.133502130009237, details={'was_impossible': False}),
#  Prediction(uid=169, iid=3, r_ui=5.0, est=3.813489259507948, details={'was_impossible': False}),
#  Prediction(uid=228, iid=362, r_ui=2.0, est=3.9271868339918043, details={'was_impossible': False}),
#  Prediction(uid=561, iid=592, r_ui=4.5, est=3.2031067053422406, details={'was_impossible': False}),
#  Prediction(uid=111, iid=1895, r_ui=4.0, est=3.1494871465926586, details={'was_impossible': False}),
#  Prediction(uid=247, iid=858, r_ui=4.0, est=3.9932176997162308, details={'was_impossible': False}),
#  Prediction(uid=135, iid=2004, r_ui=4.0, est=3.6285575793261398, details={'was_impossible': False}),
#  Prediction(uid=424, iid=2804, r_ui=3.5, est=3.8166162791570524, details={'was_impossible': False}),
#  Prediction(uid=124, iid=520, r_ui=4.0, est=3.579043818575965, details={'was_impossible': False}),
#  Prediction(uid=259, iid=2683, r_ui=4.0, est=2.690109124635175, details={'was_impossible': False}),
#  Prediction(uid=82, iid=4270, r_ui=3.0, est=3.123189919530671, details={'was_impossible': False}),
#  Prediction(uid=156, iid=3507, r_ui=4.0, est=3.9909557649590552, details={'was_impossible': False}),
#  Prediction(uid=27, iid=2944, r_ui=4.0, est=3.489968395395536, details={'was_impossible': False}),
#  Prediction(uid=294, iid=348, r_ui=2.0, est=2.860479923031408, details={'was_impossible': False}),
#  Prediction(uid=380, iid=1954, r_ui=5.0, est=4.337553434365014, details={'was_impossible': False}),
#  Prediction(uid=217, iid=1391, r_ui=3.0, est=2.5687505765567735, details={'was_impossible': False}),
#  Prediction(uid=561, iid=1, r_ui=4.0, est=3.8517146740024524, details={'was_impossible': False}),
#  Prediction(uid=215, iid=1233, r_ui=4.0, est=4.178135752402122, details={'was_impossible': False}),
#  Prediction(uid=600, iid=2096, r_ui=3.0, est=3.037104140082637, details={'was_impossible': False}),
#  Prediction(uid=116, iid=480, r_ui=4.0, est=3.740410718936414, details={'was_impossible': False}),
#  Prediction(uid=307, iid=6787, r_ui=4.0, est=3.5192684638853913, details={'was_impossible': False}),
#  Prediction(uid=331, iid=69757, r_ui=4.0, est=3.634491314605561, details={'was_impossible': False}),
#  Prediction(uid=28, iid=33679, r_ui=2.0, est=2.9716845711714077, details={'was_impossible': False}),
#  Prediction(uid=122, iid=6188, r_ui=4.5, est=4.376331461556988, details={'was_impossible': False}),
#  Prediction(uid=50, iid=32659, r_ui=2.5, est=2.595254163426114, details={'was_impossible': False}),
#  Prediction(uid=577, iid=1077, r_ui=3.0, est=3.3837593251673055, details={'was_impossible': False}),
#  Prediction(uid=266, iid=1912, r_ui=4.0, est=3.448435895115955, details={'was_impossible': False}),
#  Prediction(uid=244, iid=1370, r_ui=4.0, est=3.5939050392473297, details={'was_impossible': False}),
#  Prediction(uid=182, iid=4776, r_ui=3.0, est=3.6398034330220805, details={'was_impossible': False}),
#  Prediction(uid=469, iid=1275, r_ui=5.0, est=3.619325912954, details={'was_impossible': False}),
#  Prediction(uid=474, iid=1028, r_ui=3.0, est=3.477174943408755, details={'was_impossible': False}),
#  Prediction(uid=524, iid=329, r_ui=3.0, est=3.48712335987348, details={'was_impossible': False}),
#  Prediction(uid=438, iid=5400, r_ui=2.5, est=3.161714196636762, details={'was_impossible': False}),
#  Prediction(uid=280, iid=56949, r_ui=3.0, est=3.927809543337982, details={'was_impossible': False}),
#  Prediction(uid=249, iid=8972, r_ui=4.0, est=3.544695304449353, details={'was_impossible': False}),
#  Prediction(uid=313, iid=1219, r_ui=3.0, est=3.7618157744076464, details={'was_impossible': False}),
#  Prediction(uid=527, iid=1968, r_ui=5.0, est=4.311385137585477, details={'was_impossible': False}),
#  Prediction(uid=62, iid=527, r_ui=4.5, est=4.8023633012294304, details={'was_impossible': False}),
#  Prediction(uid=368, iid=2263, r_ui=3.0, est=2.727793889992104, details={'was_impossible': False}),
#  Prediction(uid=480, iid=43871, r_ui=3.0, est=3.2275472806407253, details={'was_impossible': False}),
#  Prediction(uid=28, iid=7025, r_ui=2.5, est=3.222058040550164, details={'was_impossible': False}),
#  Prediction(uid=475, iid=3793, r_ui=5.0, est=4.632699323616363, details={'was_impossible': False}),
#  Prediction(uid=357, iid=1027, r_ui=3.5, est=3.4516247540493157, details={'was_impossible': False}),
#  Prediction(uid=606, iid=6885, r_ui=3.0, est=3.4431115422940644, details={'was_impossible': False}),
#  Prediction(uid=608, iid=51903, r_ui=2.5, est=3.170216742476491, details={'was_impossible': False}),
#  Prediction(uid=608, iid=3273, r_ui=3.0, est=2.4737147252376426, details={'was_impossible': False}),
#  Prediction(uid=599, iid=53322, r_ui=2.5, est=2.9415037150416063, details={'was_impossible': False}),
#  Prediction(uid=410, iid=3088, r_ui=4.0, est=3.6685043845047645, details={'was_impossible': False}),
#  Prediction(uid=599, iid=2572, r_ui=3.0, est=2.7343393989421347, details={'was_impossible': False}),
#  Prediction(uid=57, iid=2083, r_ui=3.0, est=3.6785961492537416, details={'was_impossible': False}),
#  Prediction(uid=376, iid=48516, r_ui=4.5, est=4.525865580399156, details={'was_impossible': False}),
#  Prediction(uid=606, iid=2797, r_ui=3.0, est=3.795137079142498, details={'was_impossible': False}),
#  Prediction(uid=305, iid=2571, r_ui=5.0, est=4.020674005885687, details={'was_impossible': False}),
#  Prediction(uid=599, iid=2950, r_ui=2.0, est=2.051716992510705, details={'was_impossible': False}),
#  Prediction(uid=350, iid=1, r_ui=4.0, est=3.6534842474851246, details={'was_impossible': False}),
#  Prediction(uid=265, iid=79, r_ui=2.0, est=2.70566917367296, details={'was_impossible': False}),
#  Prediction(uid=159, iid=4246, r_ui=5.0, est=3.4088383273794496, details={'was_impossible': False}),
#  Prediction(uid=93, iid=86, r_ui=4.0, est=4.637866834627668, details={'was_impossible': False}),
#  Prediction(uid=567, iid=118997, r_ui=1.0, est=2.07895333111303, details={'was_impossible': False}),
#  Prediction(uid=555, iid=2797, r_ui=5.0, est=4.330225783212513, details={'was_impossible': False}),
#  Prediction(uid=380, iid=2375, r_ui=3.0, est=3.6948710662824515, details={'was_impossible': False}),
#  Prediction(uid=387, iid=1347, r_ui=3.5, est=3.0083654225838945, details={'was_impossible': False}),
#  Prediction(uid=198, iid=1682, r_ui=4.0, est=3.677335526347999, details={'was_impossible': False}),
#  Prediction(uid=436, iid=410, r_ui=3.0, est=2.8134989284315397, details={'was_impossible': False}),
#  Prediction(uid=239, iid=6537, r_ui=2.5, est=3.429436087348574, details={'was_impossible': False}),
#  Prediction(uid=20, iid=986, r_ui=3.5, est=3.6219330610597273, details={'was_impossible': False}),
#  Prediction(uid=232, iid=45221, r_ui=1.5, est=3.464416250233603, details={'was_impossible': False}),
#  Prediction(uid=280, iid=54503, r_ui=4.5, est=4.065511401304934, details={'was_impossible': False}),
#  Prediction(uid=479, iid=593, r_ui=4.0, est=4.289757986197228, details={'was_impossible': False}),
#  Prediction(uid=453, iid=356, r_ui=5.0, est=4.589558104594196, details={'was_impossible': False}),
#  Prediction(uid=249, iid=1527, r_ui=4.0, est=4.109435631344894, details={'was_impossible': False}),
#  Prediction(uid=599, iid=5072, r_ui=3.0, est=2.7912597515471886, details={'was_impossible': False}),
#  Prediction(uid=559, iid=342, r_ui=3.0, est=3.2597794042446218, details={'was_impossible': False}),
#  Prediction(uid=474, iid=7009, r_ui=3.5, est=3.1731688576680632, details={'was_impossible': False}),
#  Prediction(uid=448, iid=92665, r_ui=2.5, est=2.8581871533590233, details={'was_impossible': False}),
#  Prediction(uid=603, iid=2539, r_ui=4.0, est=3.514609297184983, details={'was_impossible': False}),
#  Prediction(uid=464, iid=2046, r_ui=3.5, est=3.4975455712132044, details={'was_impossible': False}),
#  Prediction(uid=380, iid=68358, r_ui=4.0, est=4.125547412375736, details={'was_impossible': False}),
#  Prediction(uid=564, iid=81784, r_ui=3.0, est=3.451954447817159, details={'was_impossible': False}),
#  Prediction(uid=89, iid=3599, r_ui=3.5, est=3.2356449672685472, details={'was_impossible': False}),
#  Prediction(uid=599, iid=174055, r_ui=4.0, est=2.750328585785125, details={'was_impossible': False}),
#  Prediction(uid=591, iid=2716, r_ui=3.0, est=3.451813958201077, details={'was_impossible': False}),
#  Prediction(uid=282, iid=2468, r_ui=3.0, est=3.6034384020426096, details={'was_impossible': False}),
#  Prediction(uid=83, iid=7387, r_ui=2.0, est=3.102251074269999, details={'was_impossible': False}),
#  Prediction(uid=332, iid=110, r_ui=3.5, est=3.909856571978156, details={'was_impossible': False}),
#  Prediction(uid=480, iid=44840, r_ui=3.0, est=2.7276966900034054, details={'was_impossible': False}),
#  Prediction(uid=312, iid=1387, r_ui=5.0, est=4.237016340876985, details={'was_impossible': False}),
#  Prediction(uid=249, iid=168254, r_ui=4.0, est=3.5160411933750835, details={'was_impossible': False}),
#  Prediction(uid=224, iid=2167, r_ui=1.0, est=4.125704357398691, details={'was_impossible': False}),
#  Prediction(uid=448, iid=148709, r_ui=2.0, est=2.8581871533590233, details={'was_impossible': False}),
#  Prediction(uid=561, iid=1968, r_ui=4.0, est=3.609190254469692, details={'was_impossible': False}),
#  Prediction(uid=428, iid=3440, r_ui=0.5, est=1.6898890583249957, details={'was_impossible': False}),
#  ...]

# %%
from surprise import accuracy
accuracy.rmse(pred_svd)
# Out:
# RMSE: 0.8624
# 0.8624259575760455

# %% [markdown]
# # Model 2 : SageMaker's Factorization Machines

# %%
#necessary imports
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role
from sagemaker.predictor import json_deserializer
from sagemaker.amazon.amazon_estimator import get_image_uri

from scipy.sparse import lil_matrix
import boto3, io, os

# %%
#download data from grouplens
# !wget http://files.grouplens.org/datasets/movielens/ml-100k.zip
# !unzip -o ml-100k.zip
#shuffle the data
# %cd ml-100k
# !shuf ua.base -o ua.base.shuffled
# Out:
# --2020-04-28 14:06:19--  http://files.grouplens.org/datasets/movielens/ml-100k.zip
# Resolving files.grouplens.org (files.grouplens.org)... 128.101.65.152
# Connecting to files.grouplens.org (files.grouplens.org)|128.101.65.152|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4924029 (4.7M) [application/zip]
# Saving to: ‘ml-100k.zip.1’
#
# ml-100k.zip.1       100%[===================>]   4.70M  8.23MB/s    in 0.6s
#
# 2020-04-28 14:06:20 (8.23 MB/s) - ‘ml-100k.zip.1’ saved [4924029/4924029]
#
# Archive:  ml-100k.zip
#   inflating: ml-100k/allbut.pl
#   inflating: ml-100k/mku.sh
#   inflating: ml-100k/README
#   inflating: ml-100k/u.data
#   inflating: ml-100k/u.genre
#   inflating: ml-100k/u.info
#   inflating: ml-100k/u.item
#   inflating: ml-100k/u.occupation
#   inflating: ml-100k/u.user
#   inflating: ml-100k/u1.base
#   inflating: ml-100k/u1.test
#   inflating: ml-100k/u2.base
#   inflating: ml-100k/u2.test
#   inflating: ml-100k/u3.base
#   inflating: ml-100k/u3.test
#   inflating: ml-100k/u4.base
#   inflating: ml-100k/u4.test
#   inflating: ml-100k/u5.base
#   inflating: ml-100k/u5.test
#   inflating: ml-100k/ua.base
#   inflating: ml-100k/ua.test
#   inflating: ml-100k/ub.base
#   inflating: ml-100k/ub.test
# /home/ec2-user/SageMaker/ml-100k

# %%
#load training data
train_movie_ratings= pd.read_csv('ua.base.shuffled', sep='\t', 
                                       index_col=False, names=['user_id' , 'movie_id' , 'rating'])
#load test data
test_movie_ratings= pd.read_csv('ua.test', sep='\t', 
                                      index_col=False, names=['user_id' , 'movie_id' , 'rating'])
#train_movie_ratings.head()
#test_movie_ratings.head()

# %%
n_users= train_movie_ratings['user_id'].max()
n_movies=train_movie_ratings['movie_id'].max()
n_features=n_users+n_movies

n_test_ratings=len(test_movie_ratings.index)
n_train_ratings=len(train_movie_ratings.index)

# %%
print (" number of users: ", n_users)
print (" number of movies: ", n_movies)
print (" Training Count: ", n_train_ratings)
print (" Test Count: ", n_test_ratings)
print (" Features (number of users + number of movies): ", n_features)
# Out:
#  number of users:  943
#  number of movies:  1682
#  Training Count:  90570
#  Test Count:  9430
#  Features (number of users + number of movies):  2625

# %%
#fm input
def loadDataset(data, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    y = []
    line=0
    for index, row in data.iterrows():
            X[line,row['user_id']-1] = 1
            X[line, n_users+(row['movie_id']-1)] = 1
            if int(row['rating']) >= 4:
                y.append(1)
            else:
                y.append(0)
            line=line+1

    y=np.array(y).astype('float32')            
    return X,y

X_train, y_train = loadDataset(train_movie_ratings, n_train_ratings, n_features)
X_test, y_test = loadDataset(test_movie_ratings, n_test_ratings, n_features)

# %%
print(X_test.shape)
print(y_test.shape)
assert X_test.shape  == (n_test_ratings, n_features)
assert y_test.shape  == (n_test_ratings, )
zero_labels = np.count_nonzero(y_test)
print("Test labels: %d zeros, %d ones" % (zero_labels, n_test_ratings-zero_labels))
# Out:
# (9430, 2625)
# (9430,)
# Test labels: 5469 zeros, 3961 ones

# %%
#Convert to Protobuf format for saving to S3
bucket = 'movierecom'
prefix = 'fm'

train_key      = 'train.protobuf'
train_prefix   = '{}/{}'.format(prefix, 'train')

test_key       = 'test.protobuf'
test_prefix    = '{}/{}'.format(prefix, 'test')

output_prefix  = 's3://{}/{}/output'.format(bucket, prefix)

# %%
def writeDatasetToProtobuf(X, bucket, prefix, key, d_type, y=None):
    Pbuf = io.BytesIO()
    if d_type == "sparse":
        smac.write_spmatrix_to_sparse_tensor(Pbuf, X, labels=y)
    else:
        smac.write_numpy_to_dense_tensor(Pbuf, X, labels=y)
        
    Pbuf.seek(0)
    obj = '{}/{}'.format(prefix, key)
    boto3.resource('s3').Bucket(bucket).Object(obj).upload_fileobj(Pbuf)
    return 's3://{}/{}'.format(bucket,obj)
    
fm_train_data_path = writeDatasetToProtobuf(X_train, bucket, train_prefix, train_key, "sparse", y_train)    
fm_test_data_path  = writeDatasetToProtobuf(X_test, bucket, test_prefix, test_key, "sparse", y_test)    
  
print ("Training data S3 path: ",fm_train_data_path)
print ("Test data S3 path: ",fm_test_data_path)
print ("FM model output S3 path: {}".format(output_prefix))
# Out:
# Training data S3 path:  s3://movierecom/fm/train/train.protobuf
# Test data S3 path:  s3://movierecom/fm/test/test.protobuf
# FM model output S3 path: s3://movierecom/fm/output

# %%
fm = sagemaker.estimator.Estimator(get_image_uri(boto3.Session().region_name, "factorization-machines"),
                                   get_execution_role(), 
                                   train_instance_count=1, 
                                   train_instance_type='ml.m5.large',
                                   output_path=output_prefix,
                                   sagemaker_session=sagemaker.Session())

# %%
fm.set_hyperparameters(feature_dim=n_features,
                      predictor_type='binary_classifier',
                      mini_batch_size=1000,
                      num_factors=64,
                      epochs=50)

# %%
fm.fit({'train': fm_train_data_path, 'test': fm_test_data_path})
# Out:
# 2020-04-28 14:06:55 Starting - Starting the training job...
# 2020-04-28 14:06:56 Starting - Launching requested ML instances...
# 2020-04-28 14:07:54 Starting - Preparing the instances for training......
# 2020-04-28 14:08:40 Downloading - Downloading input data...
# 2020-04-28 14:09:18 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python2.7/site-packages/pandas/util/nosetester.py:13: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing import nosetester
# [04/28/2020 14:09:33 INFO 140478314145600] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [04/28/2020 14:09:33 INFO 140478314145600] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'50', u'feature_dim': u'2625', u'mini_batch_size': u'1000', u'predictor_type': u'binary_classifier', u'num_factors': u'64'}
# [04/28/2020 14:09:33 INFO 140478314145600] Final configuration: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': u'50', u'feature_dim': u'2625', u'num_factors': u'64', u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'predictor_type': u'binary_classifier', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [04/28/2020 14:09:33 WARNING 140478314145600] Loggers have already been setup.
# Process 1 is a worker.
# [04/28/2020 14:09:34 INFO 140478314145600] Using default worker.
# [2020-04-28 14:09:34.006] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-04-28 14:09:34.017] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1, "num_bytes": 64000}
# [04/28/2020 14:09:34 INFO 140478314145600] nvidia-smi took: 0.0251410007477 secs to identify 0 gpus
# [04/28/2020 14:09:34 INFO 140478314145600] Number of GPUs being used: 0
# [04/28/2020 14:09:34 INFO 140478314145600] [Sparse network] Building a sparse network.
# [04/28/2020 14:09:34 INFO 140478314145600] Create Store: local
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 42.43206977844238, "sum": 42.43206977844238, "min": 42.43206977844238}}, "EndTime": 1588082974.057732, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082974.000808}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Max Records Seen Between Resets": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1588082974.057982, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082974.057883}
#
# [14:09:34] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.202841.0/AL2012/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [14:09:34] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.202841.0/AL2012/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [04/28/2020 14:09:34 INFO 140478314145600] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_accuracy <score>=0.549
# [04/28/2020 14:09:34 INFO 140478314145600] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_cross_entropy <loss>=0.691680419922
# [04/28/2020 14:09:34 INFO 140478314145600] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_f_1.000 <score>=0.698730794923
# [2020-04-28 14:09:35.122] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 1039, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:35 INFO 140478314145600] #quality_metric: host=algo-1, epoch=0, train binary_classification_accuracy <score>=0.549615384615
# [04/28/2020 14:09:35 INFO 140478314145600] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy <loss>=0.683836189689
# [04/28/2020 14:09:35 INFO 140478314145600] #quality_metric: host=algo-1, epoch=0, train binary_f_1.000 <score>=0.708654700551
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 50, "sum": 50.0, "min": 50}, "update.time": {"count": 1, "max": 1065.8340454101562, "sum": 1065.8340454101562, "min": 1065.8340454101562}}, "EndTime": 1588082975.124095, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082974.057801}
#
# [04/28/2020 14:09:35 INFO 140478314145600] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 92, "sum": 92.0, "min": 92}, "Total Records Seen": {"count": 1, "max": 91570, "sum": 91570.0, "min": 91570}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1588082975.124633, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 0}, "StartTime": 1588082974.058225}
#
# [04/28/2020 14:09:35 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=84916.1180436 records/second
# [04/28/2020 14:09:35 INFO 140478314145600] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_accuracy <score>=0.714
# [04/28/2020 14:09:35 INFO 140478314145600] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_cross_entropy <loss>=0.679529418945
# [04/28/2020 14:09:35 INFO 140478314145600] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_f_1.000 <score>=0.774803149606
# [2020-04-28 14:09:36.271] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 1144, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:36 INFO 140478314145600] #quality_metric: host=algo-1, epoch=1, train binary_classification_accuracy <score>=0.56732967033
# [04/28/2020 14:09:36 INFO 140478314145600] #quality_metric: host=algo-1, epoch=1, train binary_classification_cross_entropy <loss>=0.673812549633
# [04/28/2020 14:09:36 INFO 140478314145600] #quality_metric: host=algo-1, epoch=1, train binary_f_1.000 <score>=0.710805232579
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1147.292137145996, "sum": 1147.292137145996, "min": 1147.292137145996}}, "EndTime": 1588082976.272978, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082975.124228}
#
# [04/28/2020 14:09:36 INFO 140478314145600] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 183, "sum": 183.0, "min": 183}, "Total Records Seen": {"count": 1, "max": 182140, "sum": 182140.0, "min": 182140}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1588082976.27371, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 1}, "StartTime": 1588082975.125653}
#
# [04/28/2020 14:09:36 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=78858.6966038 records/second
# [04/28/2020 14:09:36 INFO 140478314145600] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_accuracy <score>=0.723
# [04/28/2020 14:09:36 INFO 140478314145600] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_cross_entropy <loss>=0.670300964355
# [04/28/2020 14:09:36 INFO 140478314145600] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_f_1.000 <score>=0.752014324082
# [2020-04-28 14:09:37.361] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 1084, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:37 INFO 140478314145600] #quality_metric: host=algo-1, epoch=2, train binary_classification_accuracy <score>=0.596010989011
# [04/28/2020 14:09:37 INFO 140478314145600] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy <loss>=0.664654704
# [04/28/2020 14:09:37 INFO 140478314145600] #quality_metric: host=algo-1, epoch=2, train binary_f_1.000 <score>=0.720703199192
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1087.226152420044, "sum": 1087.226152420044, "min": 1087.226152420044}}, "EndTime": 1588082977.362158, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082976.273371}
#
# [04/28/2020 14:09:37 INFO 140478314145600] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 274, "sum": 274.0, "min": 274}, "Total Records Seen": {"count": 1, "max": 272710, "sum": 272710.0, "min": 272710}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1588082977.3624, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 2}, "StartTime": 1588082976.274898}
#
# [04/28/2020 14:09:37 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=83272.199223 records/second
# [04/28/2020 14:09:37 INFO 140478314145600] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_accuracy <score>=0.724
# [04/28/2020 14:09:37 INFO 140478314145600] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_cross_entropy <loss>=0.660577514648
# [04/28/2020 14:09:37 INFO 140478314145600] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_f_1.000 <score>=0.752688172043
# [2020-04-28 14:09:38.372] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 1007, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:38 INFO 140478314145600] #quality_metric: host=algo-1, epoch=3, train binary_classification_accuracy <score>=0.628516483516
# [04/28/2020 14:09:38 INFO 140478314145600] #quality_metric: host=algo-1, epoch=3, train binary_classification_cross_entropy <loss>=0.655966228779
# [04/28/2020 14:09:38 INFO 140478314145600] #quality_metric: host=algo-1, epoch=3, train binary_f_1.000 <score>=0.734172636413
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 1009.9291801452637, "sum": 1009.9291801452637, "min": 1009.9291801452637}}, "EndTime": 1588082978.373122, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082977.362233}
#
# [04/28/2020 14:09:38 INFO 140478314145600] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 365, "sum": 365.0, "min": 365}, "Total Records Seen": {"count": 1, "max": 363280, "sum": 363280.0, "min": 363280}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1588082978.373486, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 3}, "StartTime": 1588082977.363164}
#
# [04/28/2020 14:09:38 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=89634.6530403 records/second
# [04/28/2020 14:09:38 INFO 140478314145600] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_accuracy <score>=0.73
# [04/28/2020 14:09:38 INFO 140478314145600] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_cross_entropy <loss>=0.651498046875
# [04/28/2020 14:09:38 INFO 140478314145600] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_f_1.000 <score>=0.758064516129
# [2020-04-28 14:09:39.262] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 887, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:39 INFO 140478314145600] #quality_metric: host=algo-1, epoch=4, train binary_classification_accuracy <score>=0.652912087912
# [04/28/2020 14:09:39 INFO 140478314145600] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy <loss>=0.647807986081
# [04/28/2020 14:09:39 INFO 140478314145600] #quality_metric: host=algo-1, epoch=4, train binary_f_1.000 <score>=0.743696899369
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 889.1308307647705, "sum": 889.1308307647705, "min": 889.1308307647705}}, "EndTime": 1588082979.263372, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082978.37319}
#
# [04/28/2020 14:09:39 INFO 140478314145600] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 456, "sum": 456.0, "min": 456}, "Total Records Seen": {"count": 1, "max": 453850, "sum": 453850.0, "min": 453850}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1588082979.263683, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 4}, "StartTime": 1588082978.374184}
#
# [04/28/2020 14:09:39 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=101808.542623 records/second
# [04/28/2020 14:09:39 INFO 140478314145600] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_classification_accuracy <score>=0.727
# [04/28/2020 14:09:39 INFO 140478314145600] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_classification_cross_entropy <loss>=0.643096679687
# [04/28/2020 14:09:39 INFO 140478314145600] #quality_metric: host=algo-1, epoch=5, batch=0 train binary_f_1.000 <score>=0.752941176471
# [2020-04-28 14:09:40.242] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 12, "duration": 976, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:40 INFO 140478314145600] #quality_metric: host=algo-1, epoch=5, train binary_classification_accuracy <score>=0.66989010989
# [04/28/2020 14:09:40 INFO 140478314145600] #quality_metric: host=algo-1, epoch=5, train binary_classification_cross_entropy <loss>=0.640211695409
# [04/28/2020 14:09:40 INFO 140478314145600] #quality_metric: host=algo-1, epoch=5, train binary_f_1.000 <score>=0.749870938733
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 978.5070419311523, "sum": 978.5070419311523, "min": 978.5070419311523}}, "EndTime": 1588082980.242867, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082979.263441}
#
# [04/28/2020 14:09:40 INFO 140478314145600] #progress_metric: host=algo-1, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 547, "sum": 547.0, "min": 547}, "Total Records Seen": {"count": 1, "max": 544420, "sum": 544420.0, "min": 544420}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1588082980.243201, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 5}, "StartTime": 1588082979.26433}
#
# [04/28/2020 14:09:40 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=92509.9208007 records/second
# [04/28/2020 14:09:40 INFO 140478314145600] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_classification_accuracy <score>=0.731
# [04/28/2020 14:09:40 INFO 140478314145600] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_classification_cross_entropy <loss>=0.63535144043
# [04/28/2020 14:09:40 INFO 140478314145600] #quality_metric: host=algo-1, epoch=6, batch=0 train binary_f_1.000 <score>=0.755676657584
# [2020-04-28 14:09:41.174] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 928, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:41 INFO 140478314145600] #quality_metric: host=algo-1, epoch=6, train binary_classification_accuracy <score>=0.682494505495
# [04/28/2020 14:09:41 INFO 140478314145600] #quality_metric: host=algo-1, epoch=6, train binary_classification_cross_entropy <loss>=0.633175523024
# [04/28/2020 14:09:41 INFO 140478314145600] #quality_metric: host=algo-1, epoch=6, train binary_f_1.000 <score>=0.75442607624
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 930.992841720581, "sum": 930.992841720581, "min": 930.992841720581}}, "EndTime": 1588082981.174922, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082980.242978}
#
# [04/28/2020 14:09:41 INFO 140478314145600] #progress_metric: host=algo-1, completed 14 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 638, "sum": 638.0, "min": 638}, "Total Records Seen": {"count": 1, "max": 634990, "sum": 634990.0, "min": 634990}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1588082981.175222, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 6}, "StartTime": 1588082980.243897}
#
# [04/28/2020 14:09:41 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=97232.6921544 records/second
# [04/28/2020 14:09:41 INFO 140478314145600] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_classification_accuracy <score>=0.734
# [04/28/2020 14:09:41 INFO 140478314145600] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_classification_cross_entropy <loss>=0.628227783203
# [04/28/2020 14:09:41 INFO 140478314145600] #quality_metric: host=algo-1, epoch=7, batch=0 train binary_f_1.000 <score>=0.75641025641
# [2020-04-28 14:09:42.027] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 16, "duration": 850, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:42 INFO 140478314145600] #quality_metric: host=algo-1, epoch=7, train binary_classification_accuracy <score>=0.692010989011
# [04/28/2020 14:09:42 INFO 140478314145600] #quality_metric: host=algo-1, epoch=7, train binary_classification_cross_entropy <loss>=0.626676928174
# [04/28/2020 14:09:42 INFO 140478314145600] #quality_metric: host=algo-1, epoch=7, train binary_f_1.000 <score>=0.757667199862
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 852.5691032409668, "sum": 852.5691032409668, "min": 852.5691032409668}}, "EndTime": 1588082982.02851, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082981.175018}
#
# [04/28/2020 14:09:42 INFO 140478314145600] #progress_metric: host=algo-1, completed 16 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 729, "sum": 729.0, "min": 729}, "Total Records Seen": {"count": 1, "max": 725560, "sum": 725560.0, "min": 725560}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1588082982.028765, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 7}, "StartTime": 1588082981.17591}
#
# [04/28/2020 14:09:42 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=106179.68776 records/second
# [04/28/2020 14:09:42 INFO 140478314145600] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_classification_accuracy <score>=0.737
# [04/28/2020 14:09:42 INFO 140478314145600] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_classification_cross_entropy <loss>=0.621684814453
# [04/28/2020 14:09:42 INFO 140478314145600] #quality_metric: host=algo-1, epoch=8, batch=0 train binary_f_1.000 <score>=0.758494031221
# [2020-04-28 14:09:43.001] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 18, "duration": 970, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=8, train binary_classification_accuracy <score>=0.699450549451
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=8, train binary_classification_cross_entropy <loss>=0.620682972667
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=8, train binary_f_1.000 <score>=0.760407176396
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 972.9969501495361, "sum": 972.9969501495361, "min": 972.9969501495361}}, "EndTime": 1588082983.002448, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082982.028594}
#
# [04/28/2020 14:09:43 INFO 140478314145600] #progress_metric: host=algo-1, completed 18 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 820, "sum": 820.0, "min": 820}, "Total Records Seen": {"count": 1, "max": 816130, "sum": 816130.0, "min": 816130}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1588082983.002804, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 8}, "StartTime": 1588082982.02942}
#
# [04/28/2020 14:09:43 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=93033.7290038 records/second
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_accuracy <score>=0.736
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_classification_cross_entropy <loss>=0.615678344727
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=9, batch=0 train binary_f_1.000 <score>=0.756906077348
# [2020-04-28 14:09:43.867] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 20, "duration": 862, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=9, train binary_classification_accuracy <score>=0.705417582418
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=9, train binary_classification_cross_entropy <loss>=0.615156304999
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=9, train binary_f_1.000 <score>=0.762246011122
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 864.1879558563232, "sum": 864.1879558563232, "min": 864.1879558563232}}, "EndTime": 1588082983.867716, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082983.002529}
#
# [04/28/2020 14:09:43 INFO 140478314145600] #progress_metric: host=algo-1, completed 20 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 911, "sum": 911.0, "min": 911}, "Total Records Seen": {"count": 1, "max": 906700, "sum": 906700.0, "min": 906700}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1588082983.867974, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 9}, "StartTime": 1588082983.003498}
#
# [04/28/2020 14:09:43 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=104752.928034 records/second
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_classification_accuracy <score>=0.733
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_classification_cross_entropy <loss>=0.610163635254
# [04/28/2020 14:09:43 INFO 140478314145600] #quality_metric: host=algo-1, epoch=10, batch=0 train binary_f_1.000 <score>=0.753006475486
# 2020-04-28 14:09:32 Training - Training image download completed. Training in progress.[2020-04-28 14:09:44.764] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 22, "duration": 893, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:44 INFO 140478314145600] #quality_metric: host=algo-1, epoch=10, train binary_classification_accuracy <score>=0.709252747253
# [04/28/2020 14:09:44 INFO 140478314145600] #quality_metric: host=algo-1, epoch=10, train binary_classification_cross_entropy <loss>=0.610058519301
# [04/28/2020 14:09:44 INFO 140478314145600] #quality_metric: host=algo-1, epoch=10, train binary_f_1.000 <score>=0.763163077143
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 896.2259292602539, "sum": 896.2259292602539, "min": 896.2259292602539}}, "EndTime": 1588082984.764859, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082983.867796}
#
# [04/28/2020 14:09:44 INFO 140478314145600] #progress_metric: host=algo-1, completed 22 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1002, "sum": 1002.0, "min": 1002}, "Total Records Seen": {"count": 1, "max": 997270, "sum": 997270.0, "min": 997270}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1588082984.765207, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 10}, "StartTime": 1588082983.868602}
#
# [04/28/2020 14:09:44 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=100998.400597 records/second
# [04/28/2020 14:09:44 INFO 140478314145600] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_classification_accuracy <score>=0.732
# [04/28/2020 14:09:44 INFO 140478314145600] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_classification_cross_entropy <loss>=0.605097167969
# [04/28/2020 14:09:44 INFO 140478314145600] #quality_metric: host=algo-1, epoch=11, batch=0 train binary_f_1.000 <score>=0.751851851852
# [2020-04-28 14:09:45.729] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 961, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:45 INFO 140478314145600] #quality_metric: host=algo-1, epoch=11, train binary_classification_accuracy <score>=0.712296703297
# [04/28/2020 14:09:45 INFO 140478314145600] #quality_metric: host=algo-1, epoch=11, train binary_classification_cross_entropy <loss>=0.605352084988
# [04/28/2020 14:09:45 INFO 140478314145600] #quality_metric: host=algo-1, epoch=11, train binary_f_1.000 <score>=0.763758425598
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 963.8688564300537, "sum": 963.8688564300537, "min": 963.8688564300537}}, "EndTime": 1588082985.729806, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082984.764962}
#
# [04/28/2020 14:09:45 INFO 140478314145600] #progress_metric: host=algo-1, completed 24 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1093, "sum": 1093.0, "min": 1093}, "Total Records Seen": {"count": 1, "max": 1087840, "sum": 1087840.0, "min": 1087840}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 13, "sum": 13.0, "min": 13}}, "EndTime": 1588082985.730118, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 11}, "StartTime": 1588082984.765906}
#
# [04/28/2020 14:09:45 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=93916.8147435 records/second
# [04/28/2020 14:09:45 INFO 140478314145600] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_classification_accuracy <score>=0.73
# [04/28/2020 14:09:45 INFO 140478314145600] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_classification_cross_entropy <loss>=0.60043737793
# [04/28/2020 14:09:45 INFO 140478314145600] #quality_metric: host=algo-1, epoch=12, batch=0 train binary_f_1.000 <score>=0.749536178108
# [2020-04-28 14:09:46.621] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 26, "duration": 889, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:46 INFO 140478314145600] #quality_metric: host=algo-1, epoch=12, train binary_classification_accuracy <score>=0.714879120879
# [04/28/2020 14:09:46 INFO 140478314145600] #quality_metric: host=algo-1, epoch=12, train binary_classification_cross_entropy <loss>=0.601001334054
# [04/28/2020 14:09:46 INFO 140478314145600] #quality_metric: host=algo-1, epoch=12, train binary_f_1.000 <score>=0.76428156116
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 891.2620544433594, "sum": 891.2620544433594, "min": 891.2620544433594}}, "EndTime": 1588082986.622149, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082985.729897}
#
# [04/28/2020 14:09:46 INFO 140478314145600] #progress_metric: host=algo-1, completed 26 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1184, "sum": 1184.0, "min": 1184}, "Total Records Seen": {"count": 1, "max": 1178410, "sum": 1178410.0, "min": 1178410}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 14, "sum": 14.0, "min": 14}}, "EndTime": 1588082986.622471, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 12}, "StartTime": 1588082985.730855}
#
# [04/28/2020 14:09:46 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=101563.106775 records/second
# [04/28/2020 14:09:46 INFO 140478314145600] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_classification_accuracy <score>=0.732
# [04/28/2020 14:09:46 INFO 140478314145600] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_classification_cross_entropy <loss>=0.596145629883
# [04/28/2020 14:09:46 INFO 140478314145600] #quality_metric: host=algo-1, epoch=13, batch=0 train binary_f_1.000 <score>=0.75092936803
# [2020-04-28 14:09:47.604] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 28, "duration": 979, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:47 INFO 140478314145600] #quality_metric: host=algo-1, epoch=13, train binary_classification_accuracy <score>=0.717241758242
# [04/28/2020 14:09:47 INFO 140478314145600] #quality_metric: host=algo-1, epoch=13, train binary_classification_cross_entropy <loss>=0.596973035205
# [04/28/2020 14:09:47 INFO 140478314145600] #quality_metric: host=algo-1, epoch=13, train binary_f_1.000 <score>=0.764912793619
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 981.7090034484863, "sum": 981.7090034484863, "min": 981.7090034484863}}, "EndTime": 1588082987.604905, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082986.622246}
#
# [04/28/2020 14:09:47 INFO 140478314145600] #progress_metric: host=algo-1, completed 28 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1275, "sum": 1275.0, "min": 1275}, "Total Records Seen": {"count": 1, "max": 1268980, "sum": 1268980.0, "min": 1268980}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1588082987.605245, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 13}, "StartTime": 1588082986.623164}
#
# [04/28/2020 14:09:47 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=92209.669849 records/second
# [04/28/2020 14:09:47 INFO 140478314145600] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_classification_accuracy <score>=0.729
# [04/28/2020 14:09:47 INFO 140478314145600] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_classification_cross_entropy <loss>=0.592186157227
# [04/28/2020 14:09:47 INFO 140478314145600] #quality_metric: host=algo-1, epoch=14, batch=0 train binary_f_1.000 <score>=0.747437092265
# [2020-04-28 14:09:48.557] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 30, "duration": 949, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:48 INFO 140478314145600] #quality_metric: host=algo-1, epoch=14, train binary_classification_accuracy <score>=0.723758241758
# [04/28/2020 14:09:48 INFO 140478314145600] #quality_metric: host=algo-1, epoch=14, train binary_classification_cross_entropy <loss>=0.593236636654
# [04/28/2020 14:09:48 INFO 140478314145600] #quality_metric: host=algo-1, epoch=14, train binary_f_1.000 <score>=0.768279193245
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 951.9059658050537, "sum": 951.9059658050537, "min": 951.9059658050537}}, "EndTime": 1588082988.557912, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082987.605}
#
# [04/28/2020 14:09:48 INFO 140478314145600] #progress_metric: host=algo-1, completed 30 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1366, "sum": 1366.0, "min": 1366}, "Total Records Seen": {"count": 1, "max": 1359550, "sum": 1359550.0, "min": 1359550}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1588082988.558285, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 14}, "StartTime": 1588082987.605939}
#
# [04/28/2020 14:09:48 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=95090.0073593 records/second
# [04/28/2020 14:09:48 INFO 140478314145600] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_classification_accuracy <score>=0.733
# [04/28/2020 14:09:48 INFO 140478314145600] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_classification_cross_entropy <loss>=0.588526367187
# [04/28/2020 14:09:48 INFO 140478314145600] #quality_metric: host=algo-1, epoch=15, batch=0 train binary_f_1.000 <score>=0.751164958062
# [2020-04-28 14:09:49.405] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 32, "duration": 845, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:49 INFO 140478314145600] #quality_metric: host=algo-1, epoch=15, train binary_classification_accuracy <score>=0.725835164835
# [04/28/2020 14:09:49 INFO 140478314145600] #quality_metric: host=algo-1, epoch=15, train binary_classification_cross_entropy <loss>=0.589764260093
# [04/28/2020 14:09:49 INFO 140478314145600] #quality_metric: host=algo-1, epoch=15, train binary_f_1.000 <score>=0.769052754353
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 847.3050594329834, "sum": 847.3050594329834, "min": 847.3050594329834}}, "EndTime": 1588082989.40634, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082988.557991}
#
# [04/28/2020 14:09:49 INFO 140478314145600] #progress_metric: host=algo-1, completed 32 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1457, "sum": 1457.0, "min": 1457}, "Total Records Seen": {"count": 1, "max": 1450120, "sum": 1450120.0, "min": 1450120}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1588082989.406649, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 15}, "StartTime": 1588082988.559004}
#
# [04/28/2020 14:09:49 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=106829.709223 records/second
# [04/28/2020 14:09:49 INFO 140478314145600] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_accuracy <score>=0.734
# [04/28/2020 14:09:49 INFO 140478314145600] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_classification_cross_entropy <loss>=0.58513659668
# [04/28/2020 14:09:49 INFO 140478314145600] #quality_metric: host=algo-1, epoch=16, batch=0 train binary_f_1.000 <score>=0.751865671642
# [2020-04-28 14:09:50.267] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 858, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:50 INFO 140478314145600] #quality_metric: host=algo-1, epoch=16, train binary_classification_accuracy <score>=0.727131868132
# [04/28/2020 14:09:50 INFO 140478314145600] #quality_metric: host=algo-1, epoch=16, train binary_classification_cross_entropy <loss>=0.586530614832
# [04/28/2020 14:09:50 INFO 140478314145600] #quality_metric: host=algo-1, epoch=16, train binary_f_1.000 <score>=0.769230769231
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 860.5990409851074, "sum": 860.5990409851074, "min": 860.5990409851074}}, "EndTime": 1588082990.268006, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082989.406428}
#
# [04/28/2020 14:09:50 INFO 140478314145600] #progress_metric: host=algo-1, completed 34 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1548, "sum": 1548.0, "min": 1548}, "Total Records Seen": {"count": 1, "max": 1540690, "sum": 1540690.0, "min": 1540690}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 18, "sum": 18.0, "min": 18}}, "EndTime": 1588082990.268295, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 16}, "StartTime": 1588082989.407359}
#
# [04/28/2020 14:09:50 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=105179.543236 records/second
# [04/28/2020 14:09:50 INFO 140478314145600] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_accuracy <score>=0.733
# [04/28/2020 14:09:50 INFO 140478314145600] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_classification_cross_entropy <loss>=0.58199005127
# [04/28/2020 14:09:50 INFO 140478314145600] #quality_metric: host=algo-1, epoch=17, batch=0 train binary_f_1.000 <score>=0.751164958062
# [2020-04-28 14:09:51.127] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 856, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:09:51 INFO 140478314145600] #quality_metric: host=algo-1, epoch=17, train binary_classification_accuracy <score>=0.728637362637
# [04/28/2020 14:09:51 INFO 140478314145600] #quality_metric: host=algo-1, epoch=17, train binary_classification_cross_entropy <loss>=0.583512887137
# [04/28/2020 14:09:51 INFO 140478314145600] #quality_metric: host=algo-1, epoch=17, train binary_f_1.000 <score>=0.769667008675
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 858.8268756866455, "sum": 858.8268756866455, "min": 858.8268756866455}}, "EndTime": 1588082991.127842, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588082990.268071}
#
# [04/28/2020 14:09:51 INFO 140478314145600] #progress_metric: host=algo-1, completed 36 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 1639, "sum": 1639.0, "min": 1639}, "Total Records Seen": {"count": 1, "max": 1631260, "sum": 1631260.0, "min": 1631260}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 19, "sum": 19.0, "min": 19}}, "EndTime": 1588082991.128099, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 17}, "StartTime": 1588082990.268983}
#
# [04/28/2020 14:09:51 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=105406.482992 records/second
# [04/28/2020 14:09:51 INFO 140478314145600] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_accuracy <score>=0.733
# [04/28/2020 14:09:51 INFO 140478314145600] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_classification_cross_entropy <loss>=0.579062805176
# [04/28/2020 14:09:51 INFO 140478314145600] #quality_metric: host=algo-1, epoch=18, batch=0 train binary_f_1.000 <score>=0.751627906977
# [2020-04-28 14:09:51.991] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 38, "duration": 861, "num_examples": 91, "num_bytes": 5796480}
# ...
#
# [04/28/2020 14:10:15 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=102650.894776 records/second
# [04/28/2020 14:10:15 INFO 140478314145600] #quality_metric: host=algo-1, epoch=45, batch=0 train binary_classification_accuracy <score>=0.748
# [04/28/2020 14:10:15 INFO 140478314145600] #quality_metric: host=algo-1, epoch=45, batch=0 train binary_classification_cross_entropy <loss>=0.538597229004
# [04/28/2020 14:10:15 INFO 140478314145600] #quality_metric: host=algo-1, epoch=45, batch=0 train binary_f_1.000 <score>=0.765799256506
# [2020-04-28 14:10:16.088] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 92, "duration": 865, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=45, train binary_classification_accuracy <score>=0.741912087912
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=45, train binary_classification_cross_entropy <loss>=0.540205143855
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=45, train binary_f_1.000 <score>=0.773637642886
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 867.6221370697021, "sum": 867.6221370697021, "min": 867.6221370697021}}, "EndTime": 1588083016.089756, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588083015.221086}
#
# [04/28/2020 14:10:16 INFO 140478314145600] #progress_metric: host=algo-1, completed 92 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 4187, "sum": 4187.0, "min": 4187}, "Total Records Seen": {"count": 1, "max": 4167220, "sum": 4167220.0, "min": 4167220}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 47, "sum": 47.0, "min": 47}}, "EndTime": 1588083016.090014, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 45}, "StartTime": 1588083015.222102}
#
# [04/28/2020 14:10:16 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=104337.066671 records/second
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=46, batch=0 train binary_classification_accuracy <score>=0.748
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=46, batch=0 train binary_classification_cross_entropy <loss>=0.537764465332
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=46, batch=0 train binary_f_1.000 <score>=0.765799256506
# [2020-04-28 14:10:16.962] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 94, "duration": 869, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=46, train binary_classification_accuracy <score>=0.742241758242
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=46, train binary_classification_cross_entropy <loss>=0.539354917421
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=46, train binary_f_1.000 <score>=0.773896279159
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 872.2488880157471, "sum": 872.2488880157471, "min": 872.2488880157471}}, "EndTime": 1588083016.962958, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588083016.089838}
#
# [04/28/2020 14:10:16 INFO 140478314145600] #progress_metric: host=algo-1, completed 94 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 4278, "sum": 4278.0, "min": 4278}, "Total Records Seen": {"count": 1, "max": 4257790, "sum": 4257790.0, "min": 4257790}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 48, "sum": 48.0, "min": 48}}, "EndTime": 1588083016.96333, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 46}, "StartTime": 1588083016.090681}
#
# [04/28/2020 14:10:16 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=103774.226635 records/second
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=47, batch=0 train binary_classification_accuracy <score>=0.747
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=47, batch=0 train binary_classification_cross_entropy <loss>=0.536955688477
# [04/28/2020 14:10:16 INFO 140478314145600] #quality_metric: host=algo-1, epoch=47, batch=0 train binary_f_1.000 <score>=0.765088207985
# [2020-04-28 14:10:17.933] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 96, "duration": 967, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:10:17 INFO 140478314145600] #quality_metric: host=algo-1, epoch=47, train binary_classification_accuracy <score>=0.742505494505
# [04/28/2020 14:10:17 INFO 140478314145600] #quality_metric: host=algo-1, epoch=47, train binary_classification_cross_entropy <loss>=0.538529082246
# [04/28/2020 14:10:17 INFO 140478314145600] #quality_metric: host=algo-1, epoch=47, train binary_f_1.000 <score>=0.774066646097
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 970.0658321380615, "sum": 970.0658321380615, "min": 970.0658321380615}}, "EndTime": 1588083017.93413, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588083016.963019}
#
# [04/28/2020 14:10:17 INFO 140478314145600] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 4369, "sum": 4369.0, "min": 4369}, "Total Records Seen": {"count": 1, "max": 4348360, "sum": 4348360.0, "min": 4348360}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 49, "sum": 49.0, "min": 49}}, "EndTime": 1588083017.934472, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 47}, "StartTime": 1588083016.964033}
#
# [04/28/2020 14:10:17 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=93315.992266 records/second
# [04/28/2020 14:10:17 INFO 140478314145600] #quality_metric: host=algo-1, epoch=48, batch=0 train binary_classification_accuracy <score>=0.745
# [04/28/2020 14:10:17 INFO 140478314145600] #quality_metric: host=algo-1, epoch=48, batch=0 train binary_classification_cross_entropy <loss>=0.536169921875
# [04/28/2020 14:10:17 INFO 140478314145600] #quality_metric: host=algo-1, epoch=48, batch=0 train binary_f_1.000 <score>=0.763231197772
# [2020-04-28 14:10:18.867] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 98, "duration": 931, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:10:18 INFO 140478314145600] #quality_metric: host=algo-1, epoch=48, train binary_classification_accuracy <score>=0.742769230769
# [04/28/2020 14:10:18 INFO 140478314145600] #quality_metric: host=algo-1, epoch=48, train binary_classification_cross_entropy <loss>=0.53772656686
# [04/28/2020 14:10:18 INFO 140478314145600] #quality_metric: host=algo-1, epoch=48, train binary_f_1.000 <score>=0.774228395062
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 933.2239627838135, "sum": 933.2239627838135, "min": 933.2239627838135}}, "EndTime": 1588083018.868475, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588083017.934221}
#
# [04/28/2020 14:10:18 INFO 140478314145600] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 4460, "sum": 4460.0, "min": 4460}, "Total Records Seen": {"count": 1, "max": 4438930, "sum": 4438930.0, "min": 4438930}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 50, "sum": 50.0, "min": 50}}, "EndTime": 1588083018.868777, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 48}, "StartTime": 1588083017.935151}
#
# [04/28/2020 14:10:18 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=96991.8322708 records/second
# [04/28/2020 14:10:18 INFO 140478314145600] #quality_metric: host=algo-1, epoch=49, batch=0 train binary_classification_accuracy <score>=0.745
# [04/28/2020 14:10:18 INFO 140478314145600] #quality_metric: host=algo-1, epoch=49, batch=0 train binary_classification_cross_entropy <loss>=0.53540612793
# [04/28/2020 14:10:18 INFO 140478314145600] #quality_metric: host=algo-1, epoch=49, batch=0 train binary_f_1.000 <score>=0.763231197772
# [2020-04-28 14:10:19.748] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 100, "duration": 877, "num_examples": 91, "num_bytes": 5796480}
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, epoch=49, train binary_classification_accuracy <score>=0.743021978022
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, epoch=49, train binary_classification_cross_entropy <loss>=0.536946357476
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, epoch=49, train binary_f_1.000 <score>=0.774352294109
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.743021978022
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.536946357476
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.774352294109
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 879.9691200256348, "sum": 879.9691200256348, "min": 879.9691200256348}}, "EndTime": 1588083019.749571, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588083018.868544}
#
# [04/28/2020 14:10:19 INFO 140478314145600] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Batches Since Last Reset": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Number of Records Since Last Reset": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Total Batches Seen": {"count": 1, "max": 4551, "sum": 4551.0, "min": 4551}, "Total Records Seen": {"count": 1, "max": 4529500, "sum": 4529500.0, "min": 4529500}, "Max Records Seen Between Resets": {"count": 1, "max": 90570, "sum": 90570.0, "min": 90570}, "Reset Count": {"count": 1, "max": 51, "sum": 51.0, "min": 51}}, "EndTime": 1588083019.749873, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 49}, "StartTime": 1588083018.869571}
#
# [04/28/2020 14:10:19 INFO 140478314145600] #throughput_metric: host=algo-1, train throughput=102867.265496 records/second
# [04/28/2020 14:10:19 WARNING 140478314145600] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/28/2020 14:10:19 INFO 140478314145600] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 2.0270347595214844, "sum": 2.0270347595214844, "min": 2.0270347595214844}}, "EndTime": 1588083019.752371, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588083019.749658}
#
# [04/28/2020 14:10:19 INFO 140478314145600] Saved checkpoint to "/tmp/tmpPfMR_a/state-0001.params"
# [2020-04-28 14:10:19.759] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 45753, "num_examples": 1, "num_bytes": 64000}
# [2020-04-28 14:10:19.809] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 49, "num_examples": 10, "num_bytes": 603520}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Number of Batches Since Last Reset": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Number of Records Since Last Reset": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Total Batches Seen": {"count": 1, "max": 10, "sum": 10.0, "min": 10}, "Total Records Seen": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Max Records Seen Between Resets": {"count": 1, "max": 9430, "sum": 9430.0, "min": 9430}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1588083019.809238, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588083019.759544}
#
# [04/28/2020 14:10:19 INFO 140478314145600] #test_score (algo-1) : ('binary_classification_accuracy', 0.684729586426299)
# [04/28/2020 14:10:19 INFO 140478314145600] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.5942866174691808)
# [04/28/2020 14:10:19 INFO 140478314145600] #test_score (algo-1) : ('binary_f_1.000', 0.711443268950791)
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.684729586426
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.594286617469
# [04/28/2020 14:10:19 INFO 140478314145600] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.711443268951
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 45855.4208278656, "sum": 45855.4208278656, "min": 45855.4208278656}, "setuptime": {"count": 1, "max": 41.6719913482666, "sum": 41.6719913482666, "min": 41.6719913482666}}, "EndTime": 1588083019.810621, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1588083019.752441}
# 2020-04-28 14:10:31 Completed - Training job completed
# Training seconds: 111
# Billable seconds: 111

# %% [markdown]
# ### Hyperparameter tuning

# %%
# use the best hyperparameters that give us the highest binary classification accuracy
fm.set_hyperparameters(feature_dim=n_features,
                      predictor_type='binary_classifier',
                      mini_batch_size=359,
                      num_factors=64,
                      epochs=403)

# %% [markdown]
# ### Deploy the model and predict

# %%
#deploy fm model and get the prediction 
fm_predictor = fm.deploy(initial_instance_count=1,
                         instance_type='ml.t2.medium')
# Out:
# ------------!

# %% [markdown]
# ### Show prediction for a particular user using endpoint

# %%
import json
from sagemaker.predictor import json_deserializer

def fm_serializer(data):
    js = {'instances': []}
    for row in data:
        js['instances'].append({'features': row.tolist()})
    return json.dumps(js)

fm_predictor.content_type = 'application/json'
fm_predictor.serializer = fm_serializer
fm_predictor.deserializer = json_deserializer

# %%
#try to predict a single record
prediction = X_test[1000].toarray()
result = fm_predictor.predict(prediction)

print(y_test[1000])
print(result)
# Out:
# 0.0
# {'predictions': [{'score': 0.5855739712715149, 'predicted_label': 1.0}]}

# %%
#try to predict a set of records(100)
predictions = []
for array in np.array_split(X_test[1000:1100].toarray(), 1):
    result = fm_predictor.predict(array)
    predictions += [r['predicted_label'] for r in result['predictions']]

predictions = np.array(predictions)
#predictions.shape

# %%
#show confusion matrix
pd.crosstab(y_test[1000:1100], predictions, rownames=['actuals'], colnames=['predictions'])
# Out:
# predictions  0.0  1.0
# actuals
# 0.0           49   12
# 1.0           22   17

# %%
# get the recommendation result for each user

# %%
def GetUserSparseMatrix(user_id):
    loc_low=user_id*10
    loc_high=loc_low+10
    print(X_test[loc_low:loc_high])

# %%
def GetUserRecIndex(user_id):
    loc_low=user_id*10
    loc_high=loc_low+10
    
    predictions = []
    for array in np.array_split(X_test[loc_low:loc_high].toarray(), 1):
        result = fm_predictor.predict(array)
        predictions += [r['predicted_label'] for r in result['predictions']]
    predictions = np.array(predictions)
   
    pred=result["predictions"]
    for i in pred:
        i["num"]=pred.index(i)
    print(pred)
   
    # fiter records with predicted_label being 1.filter lambda function 
    pred_ft= filter(lambda dic: dic["predicted_label"]==1, pred)
    pred_filter=list(pred_ft)
    #get the top 5 movie recommendaions index for each user
    pred_filter.sort(key=lambda x: x['score'], reverse=True)
    top5_num=pred_filter[:5]
    agg_num=[i["num"] for i in top5_num]
    return agg_num

# %%
user_list=[198,11,314,184,163,710,881,504,267,653]

# %%
#Get the movie recommendations for userid 198
GetUserSparseMatrix(198)
GetUserRecIndex(198)
# Out:
#   (0, 198)	1.0
#   (0, 1163)	1.0
#   (1, 198)	1.0
#   (1, 1184)	1.0
#   (2, 198)	1.0
#   (2, 1200)	1.0
#   (3, 198)	1.0
#   (3, 1210)	1.0
#   (4, 198)	1.0
#   (4, 1236)	1.0
#   (5, 198)	1.0
#   (5, 1264)	1.0
#   (6, 198)	1.0
#   (6, 1266)	1.0
#   (7, 198)	1.0
#   (7, 1415)	1.0
#   (8, 198)	1.0
#   (8, 1620)	1.0
#   (9, 198)	1.0
#   (9, 1930)	1.0
# [{'score': 0.5624204874038696, 'predicted_label': 1.0, 'num': 0}, {'score': 0.6367053985595703, 'predicted_label': 1.0, 'num': 1}, {'score': 0.5564891695976257, 'predicted_label': 1.0, 'num': 2}, {'score': 0.6409008502960205, 'predicted_label': 1.0, 'num': 3}, {'score': 0.21699607372283936, 'predicted_label': 0.0, 'num': 4}, {'score': 0.16096925735473633, 'predicted_label': 0.0, 'num': 5}, {'score': 0.38068827986717224, 'predicted_label': 0.0, 'num': 6}, {'score': 0.33846110105514526, 'predicted_label': 0.0, 'num': 7}, {'score': 0.10655821859836578, 'predicted_label': 0.0, 'num': 8}, {'score': 0.19063179194927216, 'predicted_label': 0.0, 'num': 9}]
# [3, 1, 0, 2]

# %%
#Get the movie recommendations for userid 198
GetUserSparseMatrix(11)
GetUserRecIndex(11)
# Out:
#   (0, 11)	1.0
#   (0, 1024)	1.0
#   (1, 11)	1.0
#   (1, 1038)	1.0
#   (2, 11)	1.0
#   (2, 1039)	1.0
#   (3, 11)	1.0
#   (3, 1074)	1.0
#   (4, 11)	1.0
#   (4, 1085)	1.0
#   (5, 11)	1.0
#   (5, 1114)	1.0
#   (6, 11)	1.0
#   (6, 1146)	1.0
#   (7, 11)	1.0
#   (7, 1242)	1.0
#   (8, 11)	1.0
#   (8, 1413)	1.0
#   (9, 11)	1.0
#   (9, 1677)	1.0
# [{'score': 0.7292884588241577, 'predicted_label': 1.0, 'num': 0}, {'score': 0.8354696035385132, 'predicted_label': 1.0, 'num': 1}, {'score': 0.7305694222450256, 'predicted_label': 1.0, 'num': 2}, {'score': 0.8095301389694214, 'predicted_label': 1.0, 'num': 3}, {'score': 0.6869974732398987, 'predicted_label': 1.0, 'num': 4}, {'score': 0.881394624710083, 'predicted_label': 1.0, 'num': 5}, {'score': 0.838738203048706, 'predicted_label': 1.0, 'num': 6}, {'score': 0.7037547826766968, 'predicted_label': 1.0, 'num': 7}, {'score': 0.6795014142990112, 'predicted_label': 1.0, 'num': 8}, {'score': 0.7477938532829285, 'predicted_label': 1.0, 'num': 9}]
# [5, 6, 1, 3, 9]

# %%
#Get the movie recommendations for userid 314
GetUserSparseMatrix(314)
GetUserRecIndex(314)
# Out:
#   (0, 314)	1.0
#   (0, 950)	1.0
#   (1, 314)	1.0
#   (1, 955)	1.0
#   (2, 314)	1.0
#   (2, 959)	1.0
#   (3, 314)	1.0
#   (3, 1040)	1.0
#   (4, 314)	1.0
#   (4, 1127)	1.0
#   (5, 314)	1.0
#   (5, 1215)	1.0
#   (6, 314)	1.0
#   (6, 1247)	1.0
#   (7, 314)	1.0
#   (7, 1373)	1.0
#   (8, 314)	1.0
#   (8, 1593)	1.0
#   (9, 314)	1.0
#   (9, 1599)	1.0
# [{'score': 0.7389967441558838, 'predicted_label': 1.0, 'num': 0}, {'score': 0.5338139533996582, 'predicted_label': 1.0, 'num': 1}, {'score': 0.40915682911872864, 'predicted_label': 0.0, 'num': 2}, {'score': 0.9366235136985779, 'predicted_label': 1.0, 'num': 3}, {'score': 0.8401138186454773, 'predicted_label': 1.0, 'num': 4}, {'score': 0.510281503200531, 'predicted_label': 1.0, 'num': 5}, {'score': 0.6082781553268433, 'predicted_label': 1.0, 'num': 6}, {'score': 0.5747615694999695, 'predicted_label': 1.0, 'num': 7}, {'score': 0.8331494927406311, 'predicted_label': 1.0, 'num': 8}, {'score': 0.9067280292510986, 'predicted_label': 1.0, 'num': 9}]
# [3, 9, 4, 8, 0]

# %%
# Out:
# [{'score': 0.5756932497024536, 'predicted_label': 1.0, 'num': 0},
#  {'score': 0.852996289730072, 'predicted_label': 1.0, 'num': 1},
#  {'score': 0.7887502312660217, 'predicted_label': 1.0, 'num': 2},
#  {'score': 0.5380157828330994, 'predicted_label': 1.0, 'num': 3},
#  {'score': 0.6953046917915344, 'predicted_label': 1.0, 'num': 4},
#  {'score': 0.7003229260444641, 'predicted_label': 1.0, 'num': 5},
#  {'score': 0.4947049021720886, 'predicted_label': 0.0, 'num': 6},
#  {'score': 0.5453704595565796, 'predicted_label': 1.0, 'num': 7},
#  {'score': 0.26833316683769226, 'predicted_label': 0.0, 'num': 8},
#  {'score': 0.47330421209335327, 'predicted_label': 0.0, 'num': 9}]

# %%
#Get the movie recommendations for userid 184
GetUserSparseMatrix(184)
GetUserRecIndex(184)
# Out:
#   (0, 184)	1.0
#   (0, 965)	1.0
#   (1, 184)	1.0
#   (1, 1056)	1.0
#   (2, 184)	1.0
#   (2, 1069)	1.0
#   (3, 184)	1.0
#   (3, 1141)	1.0
#   (4, 184)	1.0
#   (4, 1158)	1.0
#   (5, 184)	1.0
#   (5, 1179)	1.0
#   (6, 184)	1.0
#   (6, 1211)	1.0
#   (7, 184)	1.0
#   (7, 1229)	1.0
#   (8, 184)	1.0
#   (8, 1470)	1.0
#   (9, 184)	1.0
#   (9, 1682)	1.0
# [{'score': 0.8078263998031616, 'predicted_label': 1.0, 'num': 0}, {'score': 0.8506773710250854, 'predicted_label': 1.0, 'num': 1}, {'score': 0.9115203619003296, 'predicted_label': 1.0, 'num': 2}, {'score': 0.869451105594635, 'predicted_label': 1.0, 'num': 3}, {'score': 0.7822884321212769, 'predicted_label': 1.0, 'num': 4}, {'score': 0.7223358750343323, 'predicted_label': 1.0, 'num': 5}, {'score': 0.792839765548706, 'predicted_label': 1.0, 'num': 6}, {'score': 0.6182292699813843, 'predicted_label': 1.0, 'num': 7}, {'score': 0.7695117592811584, 'predicted_label': 1.0, 'num': 8}, {'score': 0.5357170701026917, 'predicted_label': 1.0, 'num': 9}]
# [2, 3, 1, 0, 6]

# %%
#Get the movie recommendations for userid 163
GetUserSparseMatrix(163)
GetUserRecIndex(163)
# Out:
#   (0, 163)	1.0
#   (0, 1059)	1.0
#   (1, 163)	1.0
#   (1, 1223)	1.0
#   (2, 163)	1.0
#   (2, 1241)	1.0
#   (3, 163)	1.0
#   (3, 1348)	1.0
#   (4, 163)	1.0
#   (4, 1400)	1.0
#   (5, 163)	1.0
#   (5, 1539)	1.0
#   (6, 163)	1.0
#   (6, 1562)	1.0
#   (7, 163)	1.0
#   (7, 1627)	1.0
#   (8, 163)	1.0
#   (8, 1631)	1.0
#   (9, 163)	1.0
#   (9, 1872)	1.0
# [{'score': 0.7355425953865051, 'predicted_label': 1.0, 'num': 0}, {'score': 0.6559515595436096, 'predicted_label': 1.0, 'num': 1}, {'score': 0.5307829976081848, 'predicted_label': 1.0, 'num': 2}, {'score': 0.4976571202278137, 'predicted_label': 0.0, 'num': 3}, {'score': 0.547878086566925, 'predicted_label': 1.0, 'num': 4}, {'score': 0.6790823936462402, 'predicted_label': 1.0, 'num': 5}, {'score': 0.5190690159797668, 'predicted_label': 1.0, 'num': 6}, {'score': 0.5941677093505859, 'predicted_label': 1.0, 'num': 7}, {'score': 0.550855278968811, 'predicted_label': 1.0, 'num': 8}, {'score': 0.5395510196685791, 'predicted_label': 1.0, 'num': 9}]
# [0, 5, 1, 7, 8]

# %%
#Get the movie recommendations for userid 710
GetUserSparseMatrix(710)
GetUserRecIndex(710)
# Out:
#   (0, 710)	1.0
#   (0, 1006)	1.0
#   (1, 710)	1.0
#   (1, 1037)	1.0
#   (2, 710)	1.0
#   (2, 1146)	1.0
#   (3, 710)	1.0
#   (3, 1211)	1.0
#   (4, 710)	1.0
#   (4, 1285)	1.0
#   (5, 710)	1.0
#   (5, 1363)	1.0
#   (6, 710)	1.0
#   (6, 1594)	1.0
#   (7, 710)	1.0
#   (7, 1626)	1.0
#   (8, 710)	1.0
#   (8, 1662)	1.0
#   (9, 710)	1.0
#   (9, 2016)	1.0
# [{'score': 0.9315847754478455, 'predicted_label': 1.0, 'num': 0}, {'score': 0.6610450148582458, 'predicted_label': 1.0, 'num': 1}, {'score': 0.730004072189331, 'predicted_label': 1.0, 'num': 2}, {'score': 0.823795735836029, 'predicted_label': 1.0, 'num': 3}, {'score': 0.30516061186790466, 'predicted_label': 0.0, 'num': 4}, {'score': 0.6099883913993835, 'predicted_label': 1.0, 'num': 5}, {'score': 0.6844464540481567, 'predicted_label': 1.0, 'num': 6}, {'score': 0.6452544331550598, 'predicted_label': 1.0, 'num': 7}, {'score': 0.2455539107322693, 'predicted_label': 0.0, 'num': 8}, {'score': 0.2784949839115143, 'predicted_label': 0.0, 'num': 9}]
# [0, 3, 2, 6, 1]

# %%
#Get the movie recommendations for userid 881
GetUserSparseMatrix(881)
GetUserRecIndex(881)
# Out:
#   (0, 881)	1.0
#   (0, 1013)	1.0
#   (1, 881)	1.0
#   (1, 1082)	1.0
#   (2, 881)	1.0
#   (2, 1115)	1.0
#   (3, 881)	1.0
#   (3, 1128)	1.0
#   (4, 881)	1.0
#   (4, 1135)	1.0
#   (5, 881)	1.0
#   (5, 1146)	1.0
#   (6, 881)	1.0
#   (6, 1157)	1.0
#   (7, 881)	1.0
#   (7, 1351)	1.0
#   (8, 881)	1.0
#   (8, 1457)	1.0
#   (9, 881)	1.0
#   (9, 1558)	1.0
# [{'score': 0.7156787514686584, 'predicted_label': 1.0, 'num': 0}, {'score': 0.42107969522476196, 'predicted_label': 0.0, 'num': 1}, {'score': 0.8723925948143005, 'predicted_label': 1.0, 'num': 2}, {'score': 0.7373551726341248, 'predicted_label': 1.0, 'num': 3}, {'score': 0.8172374963760376, 'predicted_label': 1.0, 'num': 4}, {'score': 0.8774584531784058, 'predicted_label': 1.0, 'num': 5}, {'score': 0.7977723479270935, 'predicted_label': 1.0, 'num': 6}, {'score': 0.30738526582717896, 'predicted_label': 0.0, 'num': 7}, {'score': 0.8935927152633667, 'predicted_label': 1.0, 'num': 8}, {'score': 0.5588003396987915, 'predicted_label': 1.0, 'num': 9}]
# [8, 5, 2, 4, 6]

# %%
#Get the movie recommendations for userid 504
GetUserSparseMatrix(504)
GetUserRecIndex(504)
# Out:
#   (0, 504)	1.0
#   (0, 1041)	1.0
#   (1, 504)	1.0
#   (1, 1082)	1.0
#   (2, 504)	1.0
#   (2, 1129)	1.0
#   (3, 504)	1.0
#   (3, 1135)	1.0
#   (4, 504)	1.0
#   (4, 1187)	1.0
#   (5, 504)	1.0
#   (5, 1440)	1.0
#   (6, 504)	1.0
#   (6, 1533)	1.0
#   (7, 504)	1.0
#   (7, 1655)	1.0
#   (8, 504)	1.0
#   (8, 1690)	1.0
#   (9, 504)	1.0
#   (9, 1931)	1.0
# [{'score': 0.41778478026390076, 'predicted_label': 0.0, 'num': 0}, {'score': 0.4515100121498108, 'predicted_label': 0.0, 'num': 1}, {'score': 0.39301714301109314, 'predicted_label': 0.0, 'num': 2}, {'score': 0.41481295228004456, 'predicted_label': 0.0, 'num': 3}, {'score': 0.457653284072876, 'predicted_label': 0.0, 'num': 4}, {'score': 0.40774717926979065, 'predicted_label': 0.0, 'num': 5}, {'score': 0.4591212570667267, 'predicted_label': 0.0, 'num': 6}, {'score': 0.43700599670410156, 'predicted_label': 0.0, 'num': 7}, {'score': 0.5131455063819885, 'predicted_label': 1.0, 'num': 8}, {'score': 0.4213246703147888, 'predicted_label': 0.0, 'num': 9}]
# [8]

# %%
#Get the movie recommendations for userid 267
GetUserSparseMatrix(267)
GetUserRecIndex(267)
# Out:
#   (0, 267)	1.0
#   (0, 944)	1.0
#   (1, 267)	1.0
#   (1, 1004)	1.0
#   (2, 267)	1.0
#   (2, 1087)	1.0
#   (3, 267)	1.0
#   (3, 1089)	1.0
#   (4, 267)	1.0
#   (4, 1159)	1.0
#   (5, 267)	1.0
#   (5, 1173)	1.0
#   (6, 267)	1.0
#   (6, 1378)	1.0
#   (7, 267)	1.0
#   (7, 1766)	1.0
#   (8, 267)	1.0
#   (8, 1872)	1.0
#   (9, 267)	1.0
#   (9, 1977)	1.0
# [{'score': 0.1136145293712616, 'predicted_label': 0.0, 'num': 0}, {'score': 0.11715386062860489, 'predicted_label': 0.0, 'num': 1}, {'score': 0.07176440954208374, 'predicted_label': 0.0, 'num': 2}, {'score': 0.18795707821846008, 'predicted_label': 0.0, 'num': 3}, {'score': 0.17907488346099854, 'predicted_label': 0.0, 'num': 4}, {'score': 0.05686260014772415, 'predicted_label': 0.0, 'num': 5}, {'score': 0.4036732316017151, 'predicted_label': 0.0, 'num': 6}, {'score': 0.1378893405199051, 'predicted_label': 0.0, 'num': 7}, {'score': 0.03702300414443016, 'predicted_label': 0.0, 'num': 8}, {'score': 0.13583563268184662, 'predicted_label': 0.0, 'num': 9}]
# []

# %%
#Get the movie recommendations for userid 653
GetUserSparseMatrix(653)
GetUserRecIndex(653)
# Out:
#   (0, 653)	1.0
#   (0, 946)	1.0
#   (1, 653)	1.0
#   (1, 1008)	1.0
#   (2, 653)	1.0
#   (2, 1164)	1.0
#   (3, 653)	1.0
#   (3, 1192)	1.0
#   (4, 653)	1.0
#   (4, 1200)	1.0
#   (5, 653)	1.0
#   (5, 1260)	1.0
#   (6, 653)	1.0
#   (6, 1365)	1.0
#   (7, 653)	1.0
#   (7, 1488)	1.0
#   (8, 653)	1.0
#   (8, 1500)	1.0
#   (9, 653)	1.0
#   (9, 1763)	1.0
# [{'score': 0.5937554836273193, 'predicted_label': 1.0, 'num': 0}, {'score': 0.5891273021697998, 'predicted_label': 1.0, 'num': 1}, {'score': 0.7062790393829346, 'predicted_label': 1.0, 'num': 2}, {'score': 0.534187912940979, 'predicted_label': 1.0, 'num': 3}, {'score': 0.7313146591186523, 'predicted_label': 1.0, 'num': 4}, {'score': 0.8397791981697083, 'predicted_label': 1.0, 'num': 5}, {'score': 0.7516844868659973, 'predicted_label': 1.0, 'num': 6}, {'score': 0.4163616895675659, 'predicted_label': 0.0, 'num': 7}, {'score': 0.5472491979598999, 'predicted_label': 1.0, 'num': 8}, {'score': 0.37141311168670654, 'predicted_label': 0.0, 'num': 9}]
# [5, 6, 4, 2, 0]

# %% [markdown]
# # test endpoint

# %%
#import sagemaker

#sagemaker.Session().delete_endpoint(fm_predictor.endpoint)

# %% [markdown]
# # Model 3 : Surprise
